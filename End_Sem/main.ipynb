# %%
import pandas as pd
import numpy as np

# Set Random Seed for all
np.random.seed(42)

# %%
# Data paths
active_companies_paths = 'Datasets/Active_companies.csv'
bharatnet_path = 'Datasets/BharatnetServiceReadyGPs.csv'
DHIS_path = 'Datasets/DHIS.csv'
IGNDPS_path = 'Datasets/IGNDPS.csv'
IGNOAPS_path = 'Datasets/IGNOAPS.csv'
IGNWPS_path = 'Datasets/IGNWPS.csv'
PMGSY_path = 'Datasets/PMGSY.csv'
TB_Lab_path = 'Datasets/TB_Laboratory_Infrastructure.csv'

# %%
# Read Data
active_companies = pd.read_csv(active_companies_paths)
bharatnet = pd.read_csv(bharatnet_path)
DHIS = pd.read_csv(DHIS_path)
IGNDPS = pd.read_csv(IGNDPS_path)
IGNOAPS = pd.read_csv(IGNOAPS_path)
IGNWPS = pd.read_csv(IGNWPS_path)
PMGSY = pd.read_csv(PMGSY_path)
TB_Lab = pd.read_csv(TB_Lab_path)

# %% [markdown]
# # Selecting subset from each dataset

# %% [markdown]
# ## Active companies

# %%
active_companies
# Out:
#                       STATES/UT  No. of Companies - Public  \
# 0   Andaman and Nicobar Islands                          2
# 1                Andhra Pradesh                         51
# 2             Arunachal Pradesh                          6
# 3                         Assam                         29
# 4                         Bihar                         66
# 5                    Chandigarh                         17
# 6                  Chhattisgarh                         32
# 7            Dadar Nagar Haveli                          3
# 8                 Daman and Diu                          1
# 9                         Delhi                        217
# 10                          Goa                         17
# 11                      Gujarat                         87
# 12                      Haryana                         28
# 13             Himachal Pradesh                         10
# 14            Jammu and Kashmir                         24
# 15                    Jharkhand                         23
# 16                    Karnataka                         85
# 17                       Kerala                         72
# 18                  Lakshadweep                          0
# 19               Madhya Pradesh                         64
# 20                  Maharashtra                        155
# 21                      Manipur                         11
# 22                    Meghalaya                         15
# 23                      Mizoram                          3
# 24                     Nagaland                          3
# 25                       Orissa                         75
# 26                  Pondicherry                          0
# 27                       Punjab                         12
# 28                    Rajasthan                         67
# 29                   Tamil Nadu                         75
# 30                    Telangana                         58
# 31                      Tripura                          9
# 32                Uttar Pradesh                        110
# 33                  Uttarakhand                         23
# 34                  West Bengal                         68
# 35                        Total                       1518
#
#     AuthorizedCapital_Public (In Crores)  No. of Companies - Private  \
# 0                                   2.00                           1
# 1                               15770.75                          36
# 2                                  10.77                           5
# 3                               17149.85                          34
# 4                               78370.30                          14
# 5                                1032.21                          18
# 6                               25215.20                           7
# 7                                 510.05                           0
# 8                                  50.00                           1
# 9                              446071.87                          41
# 10                                492.25                           4
# 11                             161751.93                          16
# 12                              70125.20                           6
# 13                               8231.20                          12
# 14                                914.15                          17
# 15                              14644.95                          25
# 16                             155578.25                          40
# 17                              14134.95                          75
# 18                                  0.00                           3
# 19                              90523.23                          29
# 20                             351155.21                          60
# 21                                266.75                           7
# 22                              10789.25                           9
# 23                                 20.10                           4
# 24                                 13.50                           6
# 25                              18379.31                          15
# 26                                  0.00                          16
# 27                              33231.95                           3
# 28                              73903.58                           3
# 29                             108402.40                          14
# 30                              44560.30                          42
# 31                               1246.00                           5
# 32                             320176.11                          12
# 33                               8867.15                           3
# 34                              52530.70                          34
# 35                            2124121.42                         617
#
#     AuthorizedCapital_Private  (In Crores)  No. of Companies - Total  \
# 0                                    50.00                         3
# 1                                  1135.99                        87
# 2                                    23.20                        11
# 3                                   938.00                        63
# 4                                   281.82                        80
# 5                                  1556.09                        35
# 6                                  1595.30                        39
# 7                                     0.00                         3
# 8                                     0.25                         2
# 9                                 10451.92                       258
# 10                                   10.76                        21
# 11                                  173.23                       103
# 12                                  680.50                        34
# 13                                 3237.50                        22
# 14                                 5062.86                        41
# 15                                 9240.15                        48
# 16                                10882.45                       125
# 17                                 3282.81                       147
# 18                                   10.10                         3
# 19                                 2046.86                        93
# 20                                 7411.08                       215
# 21                                   15.00                        18
# 22                                  210.10                        24
# 23                                   40.20                         7
# 24                                  196.00                         9
# 25                                 5256.55                        90
# 26                                  719.56                        16
# 27                                    1.07                        15
# 28                                   87.00                        70
# 29                                  121.19                        89
# 30                                  411.88                       100
# 31                                  145.00                        14
# 32                                 5188.22                       122
# 33                                   85.10                        26
# 34                                 8859.77                       102
# 35                                79407.51                      2135
#
#     Authorized Capital - Total  (In Crores)
# 0                                     52.00
# 1                                  16906.74
# 2                                     33.97
# 3                                  18087.85
# 4                                  78652.12
# 5                                   2588.30
# 6                                  26810.50
# 7                                    510.05
# 8                                     50.25
# 9                                 456523.79
# 10                                   503.01
# 11                                161925.16
# 12                                 70805.70
# 13                                 11468.70
# 14                                  5977.01
# 15                                 23885.10
# 16                                166460.70
# 17                                 17417.76
# 18                                    10.10
# 19                                 92570.09
# 20                                358566.29
# 21                                   281.75
# 22                                 10999.35
# 23                                    60.30
# 24                                   209.50
# 25                                 23635.86
# 26                                   719.56
# 27                                 33233.02
# 28                                 73990.58
# 29                                108523.59
# 30                                 44972.18
# 31                                  1391.00
# 32                                325364.33
# 33                                  8952.25
# 34                                 61390.47
# 35                               2203528.93

# %%
active_companies.columns
# Out:
# Index(['STATES/UT', 'No. of Companies - Public',
#        'AuthorizedCapital_Public (In Crores)', 'No. of Companies - Private',
#        'AuthorizedCapital_Private  (In Crores)', 'No. of Companies - Total',
#        'Authorized Capital - Total  (In Crores)'],
#       dtype='object')

# %%
# Select all columns other than [No. of Companies - Total, Authorized Capital - Total (In Crores)] into the subset
# Do not include the last row in the active_companies_subset
active_companies_subset = active_companies.iloc[:-1, :-2]
active_companies_subset
# Out:
#                       STATES/UT  No. of Companies - Public  \
# 0   Andaman and Nicobar Islands                          2
# 1                Andhra Pradesh                         51
# 2             Arunachal Pradesh                          6
# 3                         Assam                         29
# 4                         Bihar                         66
# 5                    Chandigarh                         17
# 6                  Chhattisgarh                         32
# 7            Dadar Nagar Haveli                          3
# 8                 Daman and Diu                          1
# 9                         Delhi                        217
# 10                          Goa                         17
# 11                      Gujarat                         87
# 12                      Haryana                         28
# 13             Himachal Pradesh                         10
# 14            Jammu and Kashmir                         24
# 15                    Jharkhand                         23
# 16                    Karnataka                         85
# 17                       Kerala                         72
# 18                  Lakshadweep                          0
# 19               Madhya Pradesh                         64
# 20                  Maharashtra                        155
# 21                      Manipur                         11
# 22                    Meghalaya                         15
# 23                      Mizoram                          3
# 24                     Nagaland                          3
# 25                       Orissa                         75
# 26                  Pondicherry                          0
# 27                       Punjab                         12
# 28                    Rajasthan                         67
# 29                   Tamil Nadu                         75
# 30                    Telangana                         58
# 31                      Tripura                          9
# 32                Uttar Pradesh                        110
# 33                  Uttarakhand                         23
# 34                  West Bengal                         68
#
#     AuthorizedCapital_Public (In Crores)  No. of Companies - Private  \
# 0                                   2.00                           1
# 1                               15770.75                          36
# 2                                  10.77                           5
# 3                               17149.85                          34
# 4                               78370.30                          14
# 5                                1032.21                          18
# 6                               25215.20                           7
# 7                                 510.05                           0
# 8                                  50.00                           1
# 9                              446071.87                          41
# 10                                492.25                           4
# 11                             161751.93                          16
# 12                              70125.20                           6
# 13                               8231.20                          12
# 14                                914.15                          17
# 15                              14644.95                          25
# 16                             155578.25                          40
# 17                              14134.95                          75
# 18                                  0.00                           3
# 19                              90523.23                          29
# 20                             351155.21                          60
# 21                                266.75                           7
# 22                              10789.25                           9
# 23                                 20.10                           4
# 24                                 13.50                           6
# 25                              18379.31                          15
# 26                                  0.00                          16
# 27                              33231.95                           3
# 28                              73903.58                           3
# 29                             108402.40                          14
# 30                              44560.30                          42
# 31                               1246.00                           5
# 32                             320176.11                          12
# 33                               8867.15                           3
# 34                              52530.70                          34
#
#     AuthorizedCapital_Private  (In Crores)
# 0                                    50.00
# 1                                  1135.99
# 2                                    23.20
# 3                                   938.00
# 4                                   281.82
# 5                                  1556.09
# 6                                  1595.30
# 7                                     0.00
# 8                                     0.25
# 9                                 10451.92
# 10                                   10.76
# 11                                  173.23
# 12                                  680.50
# 13                                 3237.50
# 14                                 5062.86
# 15                                 9240.15
# 16                                10882.45
# 17                                 3282.81
# 18                                   10.10
# 19                                 2046.86
# 20                                 7411.08
# 21                                   15.00
# 22                                  210.10
# 23                                   40.20
# 24                                  196.00
# 25                                 5256.55
# 26                                  719.56
# 27                                    1.07
# 28                                   87.00
# 29                                  121.19
# 30                                  411.88
# 31                                  145.00
# 32                                 5188.22
# 33                                   85.10
# 34                                 8859.77

# %%
3 # Check for any null / Nan values
active_companies_subset.isnull().sum()
# Out:
# STATES/UT                                 0
# No. of Companies - Public                 0
# AuthorizedCapital_Public (In Crores)      0
# No. of Companies - Private                0
# AuthorizedCapital_Private  (In Crores)    0
# dtype: int64

# %%
# Rename the column 'STATES/UT' to 'state_name'
active_companies_subset.rename(columns={'STATES/UT': 'state_name'}, inplace=True)

# Convert the state_name column to upper case
active_companies_subset['state_name'] = active_companies_subset['state_name'].str.upper()

# Rename the 'ANDAMAN AND NICOBAR ISLANDS' in the state_name column to 'ANDAMAN AND NICOBAR'
active_companies_subset['state_name'] = active_companies_subset['state_name'].str.replace('ANDAMAN AND NICOBAR ISLANDS', 'ANDAMAN AND NICOBAR')

# Combine 'DAMAN AND DIU' & 'DADAR NAGAR HAVELI' into 'THE DADRA & NAGAR HAVELI AND DAMAN AND DIU'
active_companies_subset['state_name'] = active_companies_subset['state_name'].str.replace('DAMAN AND DIU', 'THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU')
active_companies_subset['state_name'] = active_companies_subset['state_name'].str.replace('DADAR NAGAR HAVELI', 'THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU')

# Convert 'ORISSA' to 'ODISHA'
active_companies_subset['state_name'] = active_companies_subset['state_name'].str.replace('ORISSA', 'ODISHA')

# Convert 'PONDICHERRY' to 'PUDUCHERRY'
active_companies_subset['state_name'] = active_companies_subset['state_name'].str.replace('PONDICHERRY', 'PUDUCHERRY')

# Combine any two or more rows with the same state_names into one row with the combined state_names)
active_companies_subset = active_companies_subset.groupby('state_name').sum().reset_index()

active_companies_subset
# Out:
#                                       state_name  No. of Companies - Public  \
# 0                            ANDAMAN AND NICOBAR                          2
# 1                                 ANDHRA PRADESH                         51
# 2                              ARUNACHAL PRADESH                          6
# 3                                          ASSAM                         29
# 4                                          BIHAR                         66
# 5                                     CHANDIGARH                         17
# 6                                   CHHATTISGARH                         32
# 7                                          DELHI                        217
# 8                                            GOA                         17
# 9                                        GUJARAT                         87
# 10                                       HARYANA                         28
# 11                              HIMACHAL PRADESH                         10
# 12                             JAMMU AND KASHMIR                         24
# 13                                     JHARKHAND                         23
# 14                                     KARNATAKA                         85
# 15                                        KERALA                         72
# 16                                   LAKSHADWEEP                          0
# 17                                MADHYA PRADESH                         64
# 18                                   MAHARASHTRA                        155
# 19                                       MANIPUR                         11
# 20                                     MEGHALAYA                         15
# 21                                       MIZORAM                          3
# 22                                      NAGALAND                          3
# 23                                        ODISHA                         75
# 24                                    PUDUCHERRY                          0
# 25                                        PUNJAB                         12
# 26                                     RAJASTHAN                         67
# 27                                    TAMIL NADU                         75
# 28                                     TELANGANA                         58
# 29  THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU                          4
# 30                                       TRIPURA                          9
# 31                                 UTTAR PRADESH                        110
# 32                                   UTTARAKHAND                         23
# 33                                   WEST BENGAL                         68
#
#     AuthorizedCapital_Public (In Crores)  No. of Companies - Private  \
# 0                                   2.00                           1
# 1                               15770.75                          36
# 2                                  10.77                           5
# 3                               17149.85                          34
# 4                               78370.30                          14
# 5                                1032.21                          18
# 6                               25215.20                           7
# 7                              446071.87                          41
# 8                                 492.25                           4
# 9                              161751.93                          16
# 10                              70125.20                           6
# 11                               8231.20                          12
# 12                                914.15                          17
# 13                              14644.95                          25
# 14                             155578.25                          40
# 15                              14134.95                          75
# 16                                  0.00                           3
# 17                              90523.23                          29
# 18                             351155.21                          60
# 19                                266.75                           7
# 20                              10789.25                           9
# 21                                 20.10                           4
# 22                                 13.50                           6
# 23                              18379.31                          15
# 24                                  0.00                          16
# 25                              33231.95                           3
# 26                              73903.58                           3
# 27                             108402.40                          14
# 28                              44560.30                          42
# 29                                560.05                           1
# 30                               1246.00                           5
# 31                             320176.11                          12
# 32                               8867.15                           3
# 33                              52530.70                          34
#
#     AuthorizedCapital_Private  (In Crores)
# 0                                    50.00
# 1                                  1135.99
# 2                                    23.20
# 3                                   938.00
# 4                                   281.82
# 5                                  1556.09
# 6                                  1595.30
# 7                                 10451.92
# 8                                    10.76
# 9                                   173.23
# 10                                  680.50
# 11                                 3237.50
# 12                                 5062.86
# 13                                 9240.15
# 14                                10882.45
# 15                                 3282.81
# 16                                   10.10
# 17                                 2046.86
# 18                                 7411.08
# 19                                   15.00
# 20                                  210.10
# 21                                   40.20
# 22                                  196.00
# 23                                 5256.55
# 24                                  719.56
# 25                                    1.07
# 26                                   87.00
# 27                                  121.19
# 28                                  411.88
# 29                                    0.25
# 30                                  145.00
# 31                                 5188.22
# 32                                   85.10
# 33                                 8859.77

# %% [markdown]
# ## Bharatnet

# %%
bharatnet
# Out:
#                           State                   District  \
# 0    ANDAMAN AND NICOBAR ISLANDS                  NICOBARS
# 1    ANDAMAN AND NICOBAR ISLANDS  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR ISLANDS            SOUTH ANDAMANS
# 3                 ANDHRA PRADESH                 ANANTAPUR
# 4                 ANDHRA PRADESH                  CHITTOOR
# ..                           ...                       ...
# 711                  WEST BENGAL                     NADIA
# 712                  WEST BENGAL         PASCHIM BARDHAMAN
# 713                  WEST BENGAL           PURBA BARDHAMAN
# 714                  WEST BENGAL                   PURULIA
# 715                        Total                       NaN
#
#      Total Gram Panchayats  Service Ready Gram Panchayats  Unnamed: 4
# 0                        8                              7         NaN
# 1                       37                             37         NaN
# 2                       30                             30         NaN
# 3                     1044                            996         NaN
# 4                     1412                           1193         NaN
# ..                     ...                            ...         ...
# 711                    185                            185         NaN
# 712                     62                             56         NaN
# 713                    215                            146         NaN
# 714                    170                            170         NaN
# 715                 262489                         209828         NaN
#
# [716 rows x 5 columns]

# %%
# Select all data except the last column and the last row
bharatnet_subset = bharatnet.iloc[:-1, :-1]
bharatnet_subset
# Out:
#                           State                   District  \
# 0    ANDAMAN AND NICOBAR ISLANDS                  NICOBARS
# 1    ANDAMAN AND NICOBAR ISLANDS  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR ISLANDS            SOUTH ANDAMANS
# 3                 ANDHRA PRADESH                 ANANTAPUR
# 4                 ANDHRA PRADESH                  CHITTOOR
# ..                           ...                       ...
# 710                  WEST BENGAL               MURSHIDABAD
# 711                  WEST BENGAL                     NADIA
# 712                  WEST BENGAL         PASCHIM BARDHAMAN
# 713                  WEST BENGAL           PURBA BARDHAMAN
# 714                  WEST BENGAL                   PURULIA
#
#      Total Gram Panchayats  Service Ready Gram Panchayats
# 0                        8                              7
# 1                       37                             37
# 2                       30                             30
# 3                     1044                            996
# 4                     1412                           1193
# ..                     ...                            ...
# 710                    250                            250
# 711                    185                            185
# 712                     62                             56
# 713                    215                            146
# 714                    170                            170
#
# [715 rows x 4 columns]

# %%
# Check for any Nan or null values
bharatnet_subset.isnull().sum()
# Out:
# State                            0
# District                         0
# Total Gram Panchayats            0
# Service Ready Gram Panchayats    0
# dtype: int64

# %%
# Check for the number of unique values in the 'District' column
bharatnet_subset['District'].nunique()
# Out:
# 710

# %%
# Print the rows with duplicate distinct names
bharatnet_subset[bharatnet_subset.duplicated('District')]
# Out:
#                  State     District  Total Gram Panchayats  \
# 197    HIMACHAL PRADESH    BILASPUR                    151
# 355         MAHARASHTRA  AURANGABAD                    866
# 611  UTTAR PRADESH EAST   BALRAMPUR                    801
# 624  UTTAR PRADESH EAST    HAMIRPUR                    330
# 641  UTTAR PRADESH EAST  PRATAPGARH                   1241
#
#      Service Ready Gram Panchayats
# 197                              0
# 355                            716
# 611                            151
# 624                            301
# 641                           1145

# %%
bharatnet_subset.columns
# Out:
# Index(['State ', 'District', 'Total Gram Panchayats',
#        'Service Ready Gram Panchayats'],
#       dtype='object')

# %%
# Rename the column from 'State' to 'state_name' and 'District' to 'district_name'
bharatnet_subset.rename(columns={'State ': 'state_name', 'District': 'district_name'}, inplace=True)

# Combine the columns 'Total Gram Panchayats' and 'Service Ready Gram Panchayats' into a new column 'Percentage_Service_Ready_Gram_Panchayats'

bharatnet_subset['Percentage_Service_Ready_Gram_Panchayats'] = (bharatnet_subset['Service Ready Gram Panchayats'] / bharatnet_subset['Total Gram Panchayats']) * 100

bharatnet_subset
# Out:
#                       state_name             district_name  \
# 0    ANDAMAN AND NICOBAR ISLANDS                  NICOBARS
# 1    ANDAMAN AND NICOBAR ISLANDS  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR ISLANDS            SOUTH ANDAMANS
# 3                 ANDHRA PRADESH                 ANANTAPUR
# 4                 ANDHRA PRADESH                  CHITTOOR
# ..                           ...                       ...
# 710                  WEST BENGAL               MURSHIDABAD
# 711                  WEST BENGAL                     NADIA
# 712                  WEST BENGAL         PASCHIM BARDHAMAN
# 713                  WEST BENGAL           PURBA BARDHAMAN
# 714                  WEST BENGAL                   PURULIA
#
#      Total Gram Panchayats  Service Ready Gram Panchayats  \
# 0                        8                              7
# 1                       37                             37
# 2                       30                             30
# 3                     1044                            996
# 4                     1412                           1193
# ..                     ...                            ...
# 710                    250                            250
# 711                    185                            185
# 712                     62                             56
# 713                    215                            146
# 714                    170                            170
#
#      Percentage_Service_Ready_Gram_Panchayats
# 0                                   87.500000
# 1                                  100.000000
# 2                                  100.000000
# 3                                   95.402299
# 4                                   84.490085
# ..                                        ...
# 710                                100.000000
# 711                                100.000000
# 712                                 90.322581
# 713                                 67.906977
# 714                                100.000000
#
# [715 rows x 5 columns]

# %%
# Drop the columns 'Total Gram Panchayats' and 'Service Ready Gram Panchayats'
bharatnet_subset.drop(columns=['Total Gram Panchayats', 'Service Ready Gram Panchayats'], inplace=True)
bharatnet_subset
# Out:
#                       state_name             district_name  \
# 0    ANDAMAN AND NICOBAR ISLANDS                  NICOBARS
# 1    ANDAMAN AND NICOBAR ISLANDS  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR ISLANDS            SOUTH ANDAMANS
# 3                 ANDHRA PRADESH                 ANANTAPUR
# 4                 ANDHRA PRADESH                  CHITTOOR
# ..                           ...                       ...
# 710                  WEST BENGAL               MURSHIDABAD
# 711                  WEST BENGAL                     NADIA
# 712                  WEST BENGAL         PASCHIM BARDHAMAN
# 713                  WEST BENGAL           PURBA BARDHAMAN
# 714                  WEST BENGAL                   PURULIA
#
#      Percentage_Service_Ready_Gram_Panchayats
# 0                                   87.500000
# 1                                  100.000000
# 2                                  100.000000
# 3                                   95.402299
# 4                                   84.490085
# ..                                        ...
# 710                                100.000000
# 711                                100.000000
# 712                                 90.322581
# 713                                 67.906977
# 714                                100.000000
#
# [715 rows x 3 columns]

# %%
# Rename 'ANDAMAN AND NICOBAR ISLANDS' in 'state_name' to 'ANDAMAN AND NICOBAR'
# Rename 'UTTAR PRADESH EAST' and 'UTTAR PRADESH WEST' in 'state_name' to 'UTTAR PRADESH'
bharatnet_subset['state_name'] = bharatnet_subset['state_name'].replace('ANDAMAN AND NICOBAR ISLANDS', 'ANDAMAN AND NICOBAR')
bharatnet_subset['state_name'] = bharatnet_subset['state_name'].replace('UTTAR PRADESH EAST', 'UTTAR PRADESH')
bharatnet_subset['state_name'] = bharatnet_subset['state_name'].replace('UTTAR PRADESH WEST', 'UTTAR PRADESH')

bharatnet_subset
# Out:
#               state_name             district_name  \
# 0    ANDAMAN AND NICOBAR                  NICOBARS
# 1    ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR            SOUTH ANDAMANS
# 3         ANDHRA PRADESH                 ANANTAPUR
# 4         ANDHRA PRADESH                  CHITTOOR
# ..                   ...                       ...
# 710          WEST BENGAL               MURSHIDABAD
# 711          WEST BENGAL                     NADIA
# 712          WEST BENGAL         PASCHIM BARDHAMAN
# 713          WEST BENGAL           PURBA BARDHAMAN
# 714          WEST BENGAL                   PURULIA
#
#      Percentage_Service_Ready_Gram_Panchayats
# 0                                   87.500000
# 1                                  100.000000
# 2                                  100.000000
# 3                                   95.402299
# 4                                   84.490085
# ..                                        ...
# 710                                100.000000
# 711                                100.000000
# 712                                 90.322581
# 713                                 67.906977
# 714                                100.000000
#
# [715 rows x 3 columns]

# %%
# Replace 'S.A.S Nagar' in 'district_name' with 'SAS NAGAR'
# Replace '24 PARAGANAS SOUTH' in 'district_name' with '24 PARGANAS SOUTH'
# Replace '24 PARAGANAS NORTH' in 'district_name' with '24 PARGANAS NORTH'
# Replace 'MARIGAON' in 'district_name' with 'MORIGAON'
# Replace 'SOUTH SALMARA MANCACHAR' in 'district_name' with 'SOUTH SALMARA-MANKACHAR'
# Replace 'AURANGABAD' in 'district_name' with 'AURANAGABAD'

bharatnet_subset['district_name'] = bharatnet_subset['district_name'].replace('S.A.S Nagar', 'SAS NAGAR')
bharatnet_subset['district_name'] = bharatnet_subset['district_name'].replace('24 PARAGANAS SOUTH', '24 PARGANAS SOUTH')
bharatnet_subset['district_name'] = bharatnet_subset['district_name'].replace('24 PARAGANAS NORTH', '24 PARGANAS NORTH')
bharatnet_subset['district_name'] = bharatnet_subset['district_name'].replace('MARIGAON', 'MORIGAON')
bharatnet_subset['district_name'] = bharatnet_subset['district_name'].replace('SOUTH SALMARA MANCACHAR', 'SOUTH SALMARA-MANKACHAR')
bharatnet_subset['district_name'] = bharatnet_subset['district_name'].replace('AURANGABAD', 'AURANAGABAD')

bharatnet_subset
# Out:
#               state_name             district_name  \
# 0    ANDAMAN AND NICOBAR                  NICOBARS
# 1    ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR            SOUTH ANDAMANS
# 3         ANDHRA PRADESH                 ANANTAPUR
# 4         ANDHRA PRADESH                  CHITTOOR
# ..                   ...                       ...
# 710          WEST BENGAL               MURSHIDABAD
# 711          WEST BENGAL                     NADIA
# 712          WEST BENGAL         PASCHIM BARDHAMAN
# 713          WEST BENGAL           PURBA BARDHAMAN
# 714          WEST BENGAL                   PURULIA
#
#      Percentage_Service_Ready_Gram_Panchayats
# 0                                   87.500000
# 1                                  100.000000
# 2                                  100.000000
# 3                                   95.402299
# 4                                   84.490085
# ..                                        ...
# 710                                100.000000
# 711                                100.000000
# 712                                 90.322581
# 713                                 67.906977
# 714                                100.000000
#
# [715 rows x 3 columns]

# %% [markdown]
# ## DHIS

# %%
DHIS
# Out:
#         Sl. No.           State/UT  2022-23  2023-24
# 0             1     Andhra Pradesh     0.00     4.68
# 1             2              Assam     0.00     0.11
# 2             3              Bihar     0.00     0.58
# 3             4         Chandigarh     0.00     0.01
# 4             5       Chhattisgarh     0.00     0.40
# 5             6              Delhi     0.00     0.94
# 6             7            Gujarat     0.00     0.02
# 7             8            Haryana     0.00     0.32
# 8             9  Jammu and Kashmir     0.00     2.87
# 9            10          Jharkhand     0.00     0.04
# 10           11          Karnataka     0.00     3.28
# 11           12             Kerala     0.00     0.02
# 12           13             Ladakh     0.00     0.05
# 13           14        Maharashtra     0.00     0.31
# 14           15            Manipur     0.06     0.02
# 15           16          Meghalaya     0.00     0.00
# 16           17     Madhya Pradesh     0.00     0.99
# 17           18             Odisha     0.00     0.61
# 18           19             Punjab     0.00     0.08
# 19           20          Rajasthan     0.00     0.02
# 20           21          Telangana     0.00     0.93
# 21           22            Tripura     0.00     0.08
# 22           23      Uttar Pradesh     0.00     7.99
# 23           24        Uttarakhand     0.00     0.32
# 24           25        West Bengal     0.00     0.19
# 25  Grand Total        Grand Total     0.06    24.86

# %%
# Select all rows except the last row
# Select last and the third last columns    
DHIS_subset = DHIS.iloc[:-1, [-3, -1]]
DHIS_subset
# Out:
#              State/UT  2023-24
# 0      Andhra Pradesh     4.68
# 1               Assam     0.11
# 2               Bihar     0.58
# 3          Chandigarh     0.01
# 4        Chhattisgarh     0.40
# 5               Delhi     0.94
# 6             Gujarat     0.02
# 7             Haryana     0.32
# 8   Jammu and Kashmir     2.87
# 9           Jharkhand     0.04
# 10          Karnataka     3.28
# 11             Kerala     0.02
# 12             Ladakh     0.05
# 13        Maharashtra     0.31
# 14            Manipur     0.02
# 15          Meghalaya     0.00
# 16     Madhya Pradesh     0.99
# 17             Odisha     0.61
# 18             Punjab     0.08
# 19          Rajasthan     0.02
# 20          Telangana     0.93
# 21            Tripura     0.08
# 22      Uttar Pradesh     7.99
# 23        Uttarakhand     0.32
# 24        West Bengal     0.19

# %%
# Check for any null/ nan values
DHIS_subset.isnull().sum()
# Out:
# State/UT    0
# 2023-24     0
# dtype: int64

# %%
# Replace column name 'State/UT' with 'state_name'
DHIS_subset.rename(columns={'State/UT': 'state_name'}, inplace=True)

# Update all the state names to Upper case
DHIS_subset['state_name'] = DHIS_subset['state_name'].str.upper()
DHIS_subset
# Out:
#            state_name  2023-24
# 0      ANDHRA PRADESH     4.68
# 1               ASSAM     0.11
# 2               BIHAR     0.58
# 3          CHANDIGARH     0.01
# 4        CHHATTISGARH     0.40
# 5               DELHI     0.94
# 6             GUJARAT     0.02
# 7             HARYANA     0.32
# 8   JAMMU AND KASHMIR     2.87
# 9           JHARKHAND     0.04
# 10          KARNATAKA     3.28
# 11             KERALA     0.02
# 12             LADAKH     0.05
# 13        MAHARASHTRA     0.31
# 14            MANIPUR     0.02
# 15          MEGHALAYA     0.00
# 16     MADHYA PRADESH     0.99
# 17             ODISHA     0.61
# 18             PUNJAB     0.08
# 19          RAJASTHAN     0.02
# 20          TELANGANA     0.93
# 21            TRIPURA     0.08
# 22      UTTAR PRADESH     7.99
# 23        UTTARAKHAND     0.32
# 24        WEST BENGAL     0.19

# %%
# Rename column '2023-24' to 'Funds_Released_DHBS'
DHIS_subset.rename(columns={'2023-24': 'Funds_Released_DHBS'}, inplace=True)
DHIS_subset
# Out:
#            state_name  Funds_Released_DHBS
# 0      ANDHRA PRADESH                 4.68
# 1               ASSAM                 0.11
# 2               BIHAR                 0.58
# 3          CHANDIGARH                 0.01
# 4        CHHATTISGARH                 0.40
# 5               DELHI                 0.94
# 6             GUJARAT                 0.02
# 7             HARYANA                 0.32
# 8   JAMMU AND KASHMIR                 2.87
# 9           JHARKHAND                 0.04
# 10          KARNATAKA                 3.28
# 11             KERALA                 0.02
# 12             LADAKH                 0.05
# 13        MAHARASHTRA                 0.31
# 14            MANIPUR                 0.02
# 15          MEGHALAYA                 0.00
# 16     MADHYA PRADESH                 0.99
# 17             ODISHA                 0.61
# 18             PUNJAB                 0.08
# 19          RAJASTHAN                 0.02
# 20          TELANGANA                 0.93
# 21            TRIPURA                 0.08
# 22      UTTAR PRADESH                 7.99
# 23        UTTARAKHAND                 0.32
# 24        WEST BENGAL                 0.19

# %%
# datatype of 'Funds_Released_DHBS' column
DHIS_subset['Funds_Released_DHBS'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## IGNDPS

# %%
IGNDPS
# Out:
#         fin_year  mnth  lgd_state_code         state_name  lgd_district_code  \
# 0      2024-2025     6               1  JAMMU AND KASHMIR                 12
# 1      2024-2025     6               1  JAMMU AND KASHMIR                 13
# 2      2024-2025     6               1  JAMMU AND KASHMIR                 14
# 3      2024-2025     6               1  JAMMU AND KASHMIR                  4
# 4      2024-2025     6               1  JAMMU AND KASHMIR                  5
# ...          ...   ...             ...                ...                ...
# 12862  2024-2025     9               9      UTTAR PRADESH                164
# 12863  2024-2025     9               9      UTTAR PRADESH                169
# 12864  2024-2025     9               9      UTTAR PRADESH                171
# 12865  2024-2025     9               9      UTTAR PRADESH                172
# 12866  2024-2025     9               9      UTTAR PRADESH                184
#
#        district_name scheme_code  total_beneficiaries  total_sc  total_st  \
# 0            RAJAURI      IGNDPS                   72         3         5
# 1           SRINAGAR      IGNDPS                  110         0         0
# 2           UDHAMPUR      IGNDPS                   19         3         1
# 3               DODA      IGNDPS                  224        18        12
# 4              JAMMU      IGNDPS                   14         2         1
# ...              ...         ...                  ...       ...       ...
# 12862    MAHARAJGANJ      IGNDPS                 3203       437         5
# 12863         MEERUT      IGNDPS                  973       227         0
# 12864      MORADABAD      IGNDPS                  416        77         1
# 12865  MUZAFFARNAGAR      IGNDPS                 1996       395         0
# 12866      SONBHADRA      IGNDPS                 1491       284       127
#
#        total_gen  total_obc  total_aadhar  total_mobileno lastUpdated
# 0             64          0            69               2  2024-07-29
# 1            110          0            99              71  2024-07-29
# 2             14          1            17               4  2024-07-29
# 3            194          0           224              48  2024-07-29
# 4             10          1            14               1  2024-07-29
# ...          ...        ...           ...             ...         ...
# 12862        681       2080          1055            1911  2024-10-14
# 12863        445        301           589             680  2024-10-14
# 12864        198        140           240             256  2024-10-14
# 12865        699        902          1369            1514  2024-10-14
# 12866        327        753           448             942  2024-10-14
#
# [12867 rows x 15 columns]

# %%
IGNDPS.columns
# Out:
# Index(['fin_year', 'mnth', 'lgd_state_code', 'state_name', 'lgd_district_code',
#        'district_name', 'scheme_code', 'total_beneficiaries', 'total_sc',
#        'total_st', 'total_gen', 'total_obc', 'total_aadhar', 'total_mobileno',
#        'lastUpdated'],
#       dtype='object')

# %%
# Select the columns ['state_name', 'district_name','total_beneficiaries']
# Select all rows
IGNDPS_subset = IGNDPS[['state_name', 'district_name','total_beneficiaries']]
IGNDPS_subset
# Out:
#               state_name  district_name  total_beneficiaries
# 0      JAMMU AND KASHMIR        RAJAURI                   72
# 1      JAMMU AND KASHMIR       SRINAGAR                  110
# 2      JAMMU AND KASHMIR       UDHAMPUR                   19
# 3      JAMMU AND KASHMIR           DODA                  224
# 4      JAMMU AND KASHMIR          JAMMU                   14
# ...                  ...            ...                  ...
# 12862      UTTAR PRADESH    MAHARAJGANJ                 3203
# 12863      UTTAR PRADESH         MEERUT                  973
# 12864      UTTAR PRADESH      MORADABAD                  416
# 12865      UTTAR PRADESH  MUZAFFARNAGAR                 1996
# 12866      UTTAR PRADESH      SONBHADRA                 1491
#
# [12867 rows x 3 columns]

# %%
# Check for null values in the subset
IGNDPS_subset.isnull().sum()
# Out:
# state_name             0
# district_name          0
# total_beneficiaries    0
# dtype: int64

# %%
# Are all the district names in the subset unique?
IGNDPS_subset['district_name'].nunique()
# Out:
# 713

# %%
# Combine the rows with the same distinct and state names by adding their 'total_beneficiaries' values
IGNDPS_subset = IGNDPS_subset.groupby(['state_name', 'district_name']).sum().reset_index()
IGNDPS_subset
# Out:
#               state_name             district_name  total_beneficiaries
# 0    ANDAMAN AND NICOBAR                  NICOBARS                  150
# 1    ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN                 1780
# 2    ANDAMAN AND NICOBAR            SOUTH ANDAMANS                  766
# 3         ANDHRA PRADESH                 ANANTAPUR                88709
# 4         ANDHRA PRADESH                  CHITTOOR               127440
# ..                   ...                       ...                  ...
# 713          WEST BENGAL           PASCHIM BURDWAN                 1061
# 714          WEST BENGAL         PASCHIM MEDINIPUR                60250
# 715          WEST BENGAL             PURBA BURDWAN                49714
# 716          WEST BENGAL           PURBA MEDINIPUR                72783
# 717          WEST BENGAL                   PURULIA                28929
#
# [718 rows x 3 columns]

# %%
# Print the rows with non-unique district names
IGNDPS_subset[IGNDPS_subset.duplicated(subset='district_name', keep=False)]
# Out:
#            state_name district_name  total_beneficiaries
# 115      CHHATTISGARH     BALRAMPUR                25633
# 118      CHHATTISGARH       BIJAPUR                 6635
# 119      CHHATTISGARH      BILASPUR                77474
# 213  HIMACHAL PRADESH      BILASPUR                  648
# 215  HIMACHAL PRADESH      HAMIRPUR                 2304
# 275         KARNATAKA       BIJAPUR                18174
# 521         RAJASTHAN    PRATAPGARH                10817
# 618     UTTAR PRADESH     BALRAMPUR                11466
# 639     UTTAR PRADESH      HAMIRPUR                12708
# 666     UTTAR PRADESH    PRATAPGARH                38322

# %% [markdown]
# These are indeed unique districts, so we need not combine them.

# %% [markdown]
# ## IGNOAPS

# %%
IGNOAPS
# Out:
#         fin_year  mnth  lgd_state_code         state_name  lgd_district_code  \
# 0      2024-2025     6               1  JAMMU AND KASHMIR                 10
# 1      2024-2025     6               1  JAMMU AND KASHMIR                 13
# 2      2024-2025     6               1  JAMMU AND KASHMIR                  2
# 3      2024-2025     6               1  JAMMU AND KASHMIR                  7
# 4      2024-2025     6              10              BIHAR                188
# ...          ...   ...             ...                ...                ...
# 13081  2024-2025    10               9      UTTAR PRADESH                164
# 13082  2024-2025    10               9      UTTAR PRADESH                173
# 13083  2024-2025    10               9      UTTAR PRADESH                175
# 13084  2024-2025    10               9      UTTAR PRADESH                186
# 13085  2024-2025    10               9      UTTAR PRADESH                633
#
#           district_name scheme_code  total_beneficiaries  total_sc  total_st  \
# 0                POONCH     IGNOAPS                 3979         2      1458
# 1              SRINAGAR     IGNOAPS                 5298         0         1
# 2                BADGAM     IGNOAPS                11806       259        72
# 3                KATHUA     IGNOAPS                 4180      1345       176
# 4                ARARIA     IGNOAPS               110634     12180       333
# ...                 ...         ...                  ...       ...       ...
# 13081       MAHARAJGANJ     IGNOAPS                64345     13132       199
# 13082          PILIBHIT     IGNOAPS                55219      8905        40
# 13083        RAE BARELI     IGNOAPS                72969     25968        43
# 13084             UNNAO     IGNOAPS                81528     30868        66
# 13085  KANSHI RAM NAGAR     IGNOAPS                 7993      2102         4
#
#        total_gen  total_obc  total_aadhar  total_mobileno lastUpdated
# 0           2280        239          3696               5  2024-07-30
# 1           5296          1          5069            3399  2024-07-30
# 2          11251        224         11802            3795  2024-07-30
# 3           2210        449          4175             180  2024-07-30
# 4          96745       1376         78720           77636  2024-07-30
# ...          ...        ...           ...             ...         ...
# 13081       9075      41817         62480           59855  2024-11-07
# 13082      14430      31844         54868           54114  2024-11-07
# 13083      13576      33382         70359           68713  2024-11-07
# 13084      12527      38067         78987           72070  2024-11-07
# 13085       1424       4463          7877            7126  2024-11-07
#
# [13086 rows x 15 columns]

# %%
# Select the columns ['state_name', 'district_name','total_beneficiaries']
# Select all rows
IGNOAPS_subset = IGNOAPS[['state_name', 'district_name','total_beneficiaries']]
IGNOAPS_subset
# Out:
#               state_name     district_name  total_beneficiaries
# 0      JAMMU AND KASHMIR            POONCH                 3979
# 1      JAMMU AND KASHMIR          SRINAGAR                 5298
# 2      JAMMU AND KASHMIR            BADGAM                11806
# 3      JAMMU AND KASHMIR            KATHUA                 4180
# 4                  BIHAR            ARARIA               110634
# ...                  ...               ...                  ...
# 13081      UTTAR PRADESH       MAHARAJGANJ                64345
# 13082      UTTAR PRADESH          PILIBHIT                55219
# 13083      UTTAR PRADESH        RAE BARELI                72969
# 13084      UTTAR PRADESH             UNNAO                81528
# 13085      UTTAR PRADESH  KANSHI RAM NAGAR                 7993
#
# [13086 rows x 3 columns]

# %%
# Check for any null / nan values
IGNOAPS_subset.isnull().sum()
# Out:
# state_name             0
# district_name          0
# total_beneficiaries    0
# dtype: int64

# %%
# Are all the district names unique?
IGNOAPS_subset['district_name'].nunique()
# Out:
# 728

# %%
# Combine the rows with the same distinct and state names by adding their 'total_beneficiaries' values
IGNOAPS_subset = IGNOAPS_subset.groupby(['state_name', 'district_name']).sum().reset_index()
IGNOAPS_subset
# Out:
#               state_name             district_name  total_beneficiaries
# 0    ANDAMAN AND NICOBAR                  NICOBARS                 9404
# 1    ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN                13874
# 2    ANDAMAN AND NICOBAR            SOUTH ANDAMANS                14181
# 3         ANDHRA PRADESH                 ANANTAPUR              2659988
# 4         ANDHRA PRADESH     Alluri Sitharama Raju               165552
# ..                   ...                       ...                  ...
# 728          WEST BENGAL           PASCHIM BURDWAN               104736
# 729          WEST BENGAL         PASCHIM MEDINIPUR              1079448
# 730          WEST BENGAL             PURBA BURDWAN              1224987
# 731          WEST BENGAL           PURBA MEDINIPUR               892569
# 732          WEST BENGAL                   PURULIA               836504
#
# [733 rows x 3 columns]

# %%
# Print the rows with non-unique district names
IGNOAPS_subset[IGNOAPS_subset.duplicated(subset='district_name', keep=False)]
# Out:
#            state_name district_name  total_beneficiaries
# 127      CHHATTISGARH     BALRAMPUR               324787
# 130      CHHATTISGARH       BIJAPUR                61837
# 131      CHHATTISGARH      BILASPUR               781692
# 225  HIMACHAL PRADESH      BILASPUR               103230
# 227  HIMACHAL PRADESH      HAMIRPUR               143874
# 287         KARNATAKA       BIJAPUR               386245
# 536         RAJASTHAN    PRATAPGARH               514256
# 633     UTTAR PRADESH     BALRAMPUR               776120
# 654     UTTAR PRADESH      HAMIRPUR               957194
# 681     UTTAR PRADESH    PRATAPGARH              2404258

# %% [markdown]
# ## IGNWPS

# %%
IGNWPS
# Out:
#         fin_year  mnth  lgd_state_code         state_name  lgd_district_code  \
# 0      2024-2025     5               1  JAMMU AND KASHMIR                  1
# 1      2024-2025     5               1  JAMMU AND KASHMIR                  4
# 2      2024-2025     5               1  JAMMU AND KASHMIR                  5
# 3      2024-2025     5               1  JAMMU AND KASHMIR                623
# 4      2024-2025     5               1  JAMMU AND KASHMIR                626
# ...          ...   ...             ...                ...                ...
# 12931  2024-2025    10               9      UTTAR PRADESH                166
# 12932  2024-2025    10               9      UTTAR PRADESH                167
# 12933  2024-2025    10               9      UTTAR PRADESH                178
# 12934  2024-2025    10               9      UTTAR PRADESH                181
# 12935  2024-2025    10               9      UTTAR PRADESH                183
#
#            district_name scheme_code  total_beneficiaries  total_sc  total_st  \
# 0               ANANTNAG      IGNWPS                  203         1        15
# 1                   DODA      IGNWPS                  243         9        17
# 2                  JAMMU      IGNWPS                  432        98         3
# 3              BANDIPORA      IGNWPS                  386         0        53
# 4              GANDERWAL      IGNWPS                  183         1        45
# ...                  ...         ...                  ...       ...       ...
# 12931           MAINPURI      IGNWPS                 7773      1572         0
# 12932            MATHURA      IGNWPS                14728      4931         0
# 12933  SANT KABEER NAGAR      IGNWPS                 7284      1739         0
# 12934          SHRAVASTI      IGNWPS                 6168      1689       332
# 12935            SITAPUR      IGNWPS                44506     17780        17
#
#        total_gen  total_obc  total_aadhar  total_mobileno lastUpdated
# 0            181          6           203               4  2024-07-31
# 1            217          0           241              33  2024-07-31
# 2            305         26           431               8  2024-07-31
# 3            332          1           383              33  2024-07-31
# 4             83         54           178              99  2024-07-31
# ...          ...        ...           ...             ...         ...
# 12931       1491       4710          3802            4116  2024-11-07
# 12932       3662       6135          6786            6992  2024-11-07
# 12933       1624       3921          1418            3214  2024-11-07
# 12934       2203       1944          1649            2063  2024-11-07
# 12935      13161      13548         14267           15902  2024-11-07
#
# [12936 rows x 15 columns]

# %%
# Select the columns ['state_name', 'district_name','total_beneficiaries']
# Select all rows
IGNWPS_subset = IGNWPS[['state_name', 'district_name','total_beneficiaries']]
IGNWPS_subset
# Out:
#               state_name      district_name  total_beneficiaries
# 0      JAMMU AND KASHMIR           ANANTNAG                  203
# 1      JAMMU AND KASHMIR               DODA                  243
# 2      JAMMU AND KASHMIR              JAMMU                  432
# 3      JAMMU AND KASHMIR          BANDIPORA                  386
# 4      JAMMU AND KASHMIR          GANDERWAL                  183
# ...                  ...                ...                  ...
# 12931      UTTAR PRADESH           MAINPURI                 7773
# 12932      UTTAR PRADESH            MATHURA                14728
# 12933      UTTAR PRADESH  SANT KABEER NAGAR                 7284
# 12934      UTTAR PRADESH          SHRAVASTI                 6168
# 12935      UTTAR PRADESH            SITAPUR                44506
#
# [12936 rows x 3 columns]

# %%
# Check for any null / nan values
IGNWPS_subset.isnull().sum()
# Out:
# state_name             0
# district_name          0
# total_beneficiaries    0
# dtype: int64

# %%
# Are all the district names unique?
IGNWPS_subset['district_name'].nunique()
# Out:
# 720

# %%
# Combine the rows with the same distinct and state names by adding their 'total_beneficiaries' values
IGNWPS_subset = IGNWPS_subset.groupby(['state_name', 'district_name']).sum().reset_index()
IGNWPS_subset
# Out:
#               state_name             district_name  total_beneficiaries
# 0    ANDAMAN AND NICOBAR                  NICOBARS                 2290
# 1    ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN                 3660
# 2    ANDAMAN AND NICOBAR            SOUTH ANDAMANS                 2014
# 3         ANDHRA PRADESH                 ANANTAPUR               799621
# 4         ANDHRA PRADESH     Alluri Sitharama Raju                79096
# ..                   ...                       ...                  ...
# 720          WEST BENGAL           PASCHIM BURDWAN               139257
# 721          WEST BENGAL         PASCHIM MEDINIPUR               838762
# 722          WEST BENGAL             PURBA BURDWAN              1165481
# 723          WEST BENGAL           PURBA MEDINIPUR               580736
# 724          WEST BENGAL                   PURULIA               395344
#
# [725 rows x 3 columns]

# %%
# Print the rows with non-unique district names
IGNWPS_subset[IGNWPS_subset.duplicated(subset='district_name', keep=False)]
# Out:
#            state_name district_name  total_beneficiaries
# 127      CHHATTISGARH     BALRAMPUR                91851
# 130      CHHATTISGARH       BIJAPUR                51317
# 131      CHHATTISGARH      BILASPUR               229421
# 225  HIMACHAL PRADESH      BILASPUR                26532
# 227  HIMACHAL PRADESH      HAMIRPUR                36144
# 287         KARNATAKA       BIJAPUR               209450
# 534         RAJASTHAN    PRATAPGARH               150024
# 630     UTTAR PRADESH     BALRAMPUR               213066
# 651     UTTAR PRADESH      HAMIRPUR               141660
# 674     UTTAR PRADESH    PRATAPGARH               351864

# %% [markdown]
# ## PMGSY

# %%
PMGSY
# Out:
#                STATE_NAME             DISTRICT_NAME PMGSY_SCHEME  \
# 0     Andaman And Nicobar  North and Middle Andaman      PMGSY-I
# 1     Andaman And Nicobar             South Andaman      PMGSY-I
# 2          Andhra Pradesh     Alluri Sitharama Raju      PMGSY-I
# 3          Andhra Pradesh     Alluri Sitharama Raju     PMGSY-II
# 4          Andhra Pradesh                Anakapalli      PMGSY-I
# ...                   ...                       ...          ...
# 2252          West Bengal           Purba Medinipur     PMGSY-II
# 2253          West Bengal                   Purulia      PMGSY-I
# 2254          West Bengal             Siliguri M.P.      PMGSY-I
# 2255          West Bengal             Siliguri M.P.     PMGSY-II
# 2256          West Bengal         South 24-Parganas    PMGSY-III
#
#       NO_OF_ROAD_WORK_SANCTIONED  NO_OF_BRIDGES_SANCTIONED  \
# 0                             32                         0
# 1                             32                         0
# 2                            472                        17
# 3                              2                         0
# 4                            195                         8
# ...                          ...                       ...
# 2252                          11                         2
# 2253                         415                         0
# 2254                          94                         1
# 2255                           8                         0
# 2256                          47                         0
#
#       NO_OF_ROAD_WORKS_COMPLETED  NO_OF_BRIDGES_COMPLETED  \
# 0                             32                        0
# 1                             31                        0
# 2                            467                       14
# 3                              2                        0
# 4                            195                        8
# ...                          ...                      ...
# 2252                          11                        2
# 2253                         415                        0
# 2254                          94                        1
# 2255                           8                        0
# 2256                           2                        0
#
#       NO_OF_ROAD_WORKS_BALANCE  NO_OF_BRIDGES_BALANCE  \
# 0                            0                      0
# 1                            1                      0
# 2                            5                      3
# 3                            0                      0
# 4                            0                      0
# ...                        ...                    ...
# 2252                         0                      0
# 2253                         0                      0
# 2254                         0                      0
# 2255                         0                      0
# 2256                        45                      0
#
#       LENGTH_OF_ROAD_WORK_SANCTIONED_KM  COST_OF_WORKS_SANCTIONED_LAKHS  \
# 0                                60.169                        24.69080
# 1                                40.146                        18.53750
# 2                              1952.378                       775.69920
# 3                                14.000                         8.93850
# 4                               483.715                       158.07450
# ...                                 ...                             ...
# 2252                            101.850                        82.46289
# 2253                           2217.411                       870.67731
# 2254                            354.167                       121.07113
# 2255                             35.022                        24.46831
# 2256                            320.352                       226.43533
#
#       LENGTH_OF_ROAD_WORK_COMPLETED_KM  EXPENDITURE_OCCURED_LAKHS  \
# 0                               59.190                    19.5518
# 1                               39.287                    11.6894
# 2                             1809.482                   697.8523
# 3                               12.395                     6.4294
# 4                              465.672                   140.3410
# ...                                ...                        ...
# 2252                           101.408                    77.8186
# 2253                          2208.023                   672.5263
# 2254                           352.332                   110.1007
# 2255                            34.852                    19.3307
# 2256                            25.140                    18.2737
#
#       LENGTH_OF_ROAD_WORK_BALANCE_KM
# 0                              0.000
# 1                              0.541
# 2                             24.340
# 3                              0.000
# 4                              0.000
# ...                              ...
# 2252                           0.000
# 2253                           0.000
# 2254                           0.000
# 2255                           0.000
# 2256                         295.212
#
# [2257 rows x 14 columns]

# %% [markdown]
# ### Dividing the dataset into the 5 schemes (['PMGSY-II' 'PMGSY-I' 'PMGSY-III' 'RCPLWEA' 'PM-JANMAN'])
#
# It seems that the PMGSY scheme is not a single scheme but a collection of schemes. It contains five different schemes as listed under the column 'PMGSY_SCHEME'.
#
# On some internet search, it was found that these are different legs of the broader PMGSY scheme, launched either as a phase-wise scheme or with a focus in hand. The five schemes are:
#
# 1. **PMGSY-I (Pradhan Mantri Gram Sadak Yojana - Phase I):**
#    Focused on providing all-weather road connectivity to unconnected rural habitations, mainly targeting villages with populations over 500 in plains and 250 in hilly, tribal, or desert areas.
#
# 2. **PMGSY-II (Pradhan Mantri Gram Sadak Yojana - Phase II):**
#    Launched to upgrade and consolidate the rural road network by improving existing roads that connect rural areas to key facilities like markets, schools, and health centers.
#
# 3. **PMGSY-III (Pradhan Mantri Gram Sadak Yojana - Phase III):**
#    Aims to further enhance rural road connectivity by constructing roads that improve access to agricultural markets, higher education institutions, and healthcare services, promoting rural economic growth.
#
# 4. **RCPLWEA (Road Connectivity Project for Left Wing Extremism Affected Areas):**
#    Designed to improve road infrastructure in regions affected by Left-Wing Extremism, with the goal of enhancing mobility, security, and development in these insurgency-hit areas.
#
# 5. **PM-JANMAN (Pradhan Mantri Janjatiya Adivasi Nyay Mahabhiyan):**
#    Focused on providing justice, development, and infrastructure, especially road connectivity, to tribal and Adivasi communities, addressing socio-economic inequalities and promoting their welfare.
#
#
# Thus, we will consider each of these schemes as a separate scheme and analyze them individually.

# %%
# Dividing the dataset into the 5 schemes (['PMGSY-I', 'PMGSY-II', 'PMGSY-III' 'RCPLWEA' 'PM-JANMAN'])

PMGSY1 = PMGSY[PMGSY['PMGSY_SCHEME'] == 'PMGSY-I']
PMGSY2 = PMGSY[PMGSY['PMGSY_SCHEME'] == 'PMGSY-II']
PMGSY3 = PMGSY[PMGSY['PMGSY_SCHEME'] == 'PMGSY-III']
RCPLWEA = PMGSY[PMGSY['PMGSY_SCHEME'] == 'RCPLWEA']
PMGSY_JANMAN = PMGSY[PMGSY['PMGSY_SCHEME'] == 'PM-JANMAN']

# %% [markdown]
# ### PMGSY1_SCHEME

# %%
PMGSY1
# Out:
#                STATE_NAME             DISTRICT_NAME PMGSY_SCHEME  \
# 0     Andaman And Nicobar  North and Middle Andaman      PMGSY-I
# 1     Andaman And Nicobar             South Andaman      PMGSY-I
# 2          Andhra Pradesh     Alluri Sitharama Raju      PMGSY-I
# 4          Andhra Pradesh                Anakapalli      PMGSY-I
# 5          Andhra Pradesh                 Anantapur      PMGSY-I
# ...                   ...                       ...          ...
# 2246          West Bengal                 Kalimpong      PMGSY-I
# 2249          West Bengal         North 24 Parganas      PMGSY-I
# 2251          West Bengal             Purba Burdwan      PMGSY-I
# 2253          West Bengal                   Purulia      PMGSY-I
# 2254          West Bengal             Siliguri M.P.      PMGSY-I
#
#       NO_OF_ROAD_WORK_SANCTIONED  NO_OF_BRIDGES_SANCTIONED  \
# 0                             32                         0
# 1                             32                         0
# 2                            472                        17
# 4                            195                         8
# 5                            207                        22
# ...                          ...                       ...
# 2246                          80                         2
# 2249                         468                         0
# 2251                         253                         4
# 2253                         415                         0
# 2254                          94                         1
#
#       NO_OF_ROAD_WORKS_COMPLETED  NO_OF_BRIDGES_COMPLETED  \
# 0                             32                        0
# 1                             31                        0
# 2                            467                       14
# 4                            195                        8
# 5                            207                       21
# ...                          ...                      ...
# 2246                          80                        2
# 2249                         467                        0
# 2251                         253                        4
# 2253                         415                        0
# 2254                          94                        1
#
#       NO_OF_ROAD_WORKS_BALANCE  NO_OF_BRIDGES_BALANCE  \
# 0                            0                      0
# 1                            1                      0
# 2                            5                      3
# 4                            0                      0
# 5                            0                      1
# ...                        ...                    ...
# 2246                         0                      0
# 2249                         1                      0
# 2251                         0                      0
# 2253                         0                      0
# 2254                         0                      0
#
#       LENGTH_OF_ROAD_WORK_SANCTIONED_KM  COST_OF_WORKS_SANCTIONED_LAKHS  \
# 0                                60.169                        24.69080
# 1                                40.146                        18.53750
# 2                              1952.378                       775.69920
# 4                               483.715                       158.07450
# 5                               862.650                       214.77720
# ...                                 ...                             ...
# 2246                            432.841                       290.86240
# 2249                           2160.540                      1095.63808
# 2251                           1349.102                       543.36375
# 2253                           2217.411                       870.67731
# 2254                            354.167                       121.07113
#
#       LENGTH_OF_ROAD_WORK_COMPLETED_KM  EXPENDITURE_OCCURED_LAKHS  \
# 0                               59.190                    19.5518
# 1                               39.287                    11.6894
# 2                             1809.482                   697.8523
# 4                              465.672                   140.3410
# 5                              854.249                   213.8990
# ...                                ...                        ...
# 2246                           427.362                   285.1607
# 2249                          2146.782                  1006.0229
# 2251                          1319.389                   495.9742
# 2253                          2208.023                   672.5263
# 2254                           352.332                   110.1007
#
#       LENGTH_OF_ROAD_WORK_BALANCE_KM
# 0                              0.000
# 1                              0.541
# 2                             24.340
# 4                              0.000
# 5                              0.000
# ...                              ...
# 2246                           0.000
# 2249                           2.000
# 2251                           0.000
# 2253                           0.000
# 2254                           0.000
#
# [721 rows x 14 columns]

# %%
PMGSY1.columns
# Out:
# Index(['STATE_NAME', 'DISTRICT_NAME', 'PMGSY_SCHEME',
#        'NO_OF_ROAD_WORK_SANCTIONED', 'NO_OF_BRIDGES_SANCTIONED',
#        'NO_OF_ROAD_WORKS_COMPLETED', 'NO_OF_BRIDGES_COMPLETED',
#        'NO_OF_ROAD_WORKS_BALANCE', 'NO_OF_BRIDGES_BALANCE',
#        'LENGTH_OF_ROAD_WORK_SANCTIONED_KM', 'COST_OF_WORKS_SANCTIONED_LAKHS',
#        'LENGTH_OF_ROAD_WORK_COMPLETED_KM', 'EXPENDITURE_OCCURED_LAKHS',
#        'LENGTH_OF_ROAD_WORK_BALANCE_KM'],
#       dtype='object')

# %%
# Select all rows of columns ['STATE_NAME', 'DISTRICT_NAME', 'LENGTH_OF_ROAD_WORK_SANCTIONED_KM', 'COST_OF_WORKS_SANCTIONED_LAKHS']
PMGSY1_subset = PMGSY1[['STATE_NAME', 'DISTRICT_NAME', 'LENGTH_OF_ROAD_WORK_SANCTIONED_KM', 'COST_OF_WORKS_SANCTIONED_LAKHS']]
# Reset index
PMGSY1_subset.reset_index(drop=True, inplace=True)
PMGSY1_subset
# Out:
#               STATE_NAME             DISTRICT_NAME  \
# 0    Andaman And Nicobar  North and Middle Andaman
# 1    Andaman And Nicobar             South Andaman
# 2         Andhra Pradesh     Alluri Sitharama Raju
# 3         Andhra Pradesh                Anakapalli
# 4         Andhra Pradesh                 Anantapur
# ..                   ...                       ...
# 716          West Bengal                 Kalimpong
# 717          West Bengal         North 24 Parganas
# 718          West Bengal             Purba Burdwan
# 719          West Bengal                   Purulia
# 720          West Bengal             Siliguri M.P.
#
#      LENGTH_OF_ROAD_WORK_SANCTIONED_KM  COST_OF_WORKS_SANCTIONED_LAKHS
# 0                               60.169                        24.69080
# 1                               40.146                        18.53750
# 2                             1952.378                       775.69920
# 3                              483.715                       158.07450
# 4                              862.650                       214.77720
# ..                                 ...                             ...
# 716                            432.841                       290.86240
# 717                           2160.540                      1095.63808
# 718                           1349.102                       543.36375
# 719                           2217.411                       870.67731
# 720                            354.167                       121.07113
#
# [721 rows x 4 columns]

# %%
# Number of unique districts
PMGSY1_subset['DISTRICT_NAME'].nunique()
# Out:
# 715

# %%
# Combine the rows with the same distinct and state names by adding their corresponding column values
PMGSY1_subset = PMGSY1_subset.groupby(['STATE_NAME', 'DISTRICT_NAME']).sum().reset_index()
PMGSY1_subset
# Out:
#               STATE_NAME             DISTRICT_NAME  \
# 0    Andaman And Nicobar                   Nicobar
# 1    Andaman And Nicobar  North and Middle Andaman
# 2    Andaman And Nicobar             South Andaman
# 3         Andhra Pradesh     Alluri Sitharama Raju
# 4         Andhra Pradesh                Anakapalli
# ..                   ...                       ...
# 716          West Bengal           Purba Medinipur
# 717          West Bengal                   Purulia
# 718          West Bengal             Siliguri M.P.
# 719          West Bengal         South 24-Parganas
# 720          West Bengal             Uttardinajpur
#
#      LENGTH_OF_ROAD_WORK_SANCTIONED_KM  COST_OF_WORKS_SANCTIONED_LAKHS
# 0                                2.969                         1.38570
# 1                               60.169                        24.69080
# 2                               40.146                        18.53750
# 3                             1952.378                       775.69920
# 4                              483.715                       158.07450
# ..                                 ...                             ...
# 716                           1304.068                       658.48287
# 717                           2217.411                       870.67731
# 718                            354.167                       121.07113
# 719                           1603.630                       838.97300
# 720                           1463.526                       662.19252
#
# [721 rows x 4 columns]

# %% [markdown]
# ### PMGSY2_SCHEME

# %%
PMGSY2
# Out:
#           STATE_NAME          DISTRICT_NAME PMGSY_SCHEME  \
# 3     Andhra Pradesh  Alluri Sitharama Raju     PMGSY-II
# 6     Andhra Pradesh              Anantapur     PMGSY-II
# 10    Andhra Pradesh                Bapatla     PMGSY-II
# 15    Andhra Pradesh                Kurnool     PMGSY-II
# 16    Andhra Pradesh                Nandyal     PMGSY-II
# ...              ...                    ...          ...
# 2244     West Bengal                Birbhum     PMGSY-II
# 2245     West Bengal                Hooghly     PMGSY-II
# 2247     West Bengal            Murshidabad     PMGSY-II
# 2252     West Bengal        Purba Medinipur     PMGSY-II
# 2255     West Bengal          Siliguri M.P.     PMGSY-II
#
#       NO_OF_ROAD_WORK_SANCTIONED  NO_OF_BRIDGES_SANCTIONED  \
# 3                              2                         0
# 6                              8                         0
# 10                             6                         0
# 15                             9                         1
# 16                             5                         0
# ...                          ...                       ...
# 2244                           7                         0
# 2245                          15                         0
# 2247                          14                         0
# 2252                          11                         2
# 2255                           8                         0
#
#       NO_OF_ROAD_WORKS_COMPLETED  NO_OF_BRIDGES_COMPLETED  \
# 3                              2                        0
# 6                              8                        0
# 10                             6                        0
# 15                             9                        1
# 16                             5                        0
# ...                          ...                      ...
# 2244                           7                        0
# 2245                          15                        0
# 2247                          14                        0
# 2252                          11                        2
# 2255                           8                        0
#
#       NO_OF_ROAD_WORKS_BALANCE  NO_OF_BRIDGES_BALANCE  \
# 3                            0                      0
# 6                            0                      0
# 10                           0                      0
# 15                           0                      0
# 16                           0                      0
# ...                        ...                    ...
# 2244                         0                      0
# 2245                         0                      0
# 2247                         0                      0
# 2252                         0                      0
# 2255                         0                      0
#
#       LENGTH_OF_ROAD_WORK_SANCTIONED_KM  COST_OF_WORKS_SANCTIONED_LAKHS  \
# 3                                14.000                         8.93850
# 6                                75.020                        29.99530
# 10                               53.430                        28.74360
# 15                               65.660                        28.50850
# 16                               54.930                        32.64160
# ...                                 ...                             ...
# 2244                             76.750                        61.97305
# 2245                             96.426                        74.68126
# 2247                            162.946                       105.63891
# 2252                            101.850                        82.46289
# 2255                             35.022                        24.46831
#
#       LENGTH_OF_ROAD_WORK_COMPLETED_KM  EXPENDITURE_OCCURED_LAKHS  \
# 3                               12.395                     6.4294
# 6                               74.961                    27.1823
# 10                              53.763                    24.3953
# 15                              65.021                    26.8076
# 16                              53.622                    28.8901
# ...                                ...                        ...
# 2244                            76.221                    59.7094
# 2245                            96.426                    64.3534
# 2247                           162.849                    99.9851
# 2252                           101.408                    77.8186
# 2255                            34.852                    19.3307
#
#       LENGTH_OF_ROAD_WORK_BALANCE_KM
# 3                                0.0
# 6                                0.0
# 10                               0.0
# 15                               0.0
# 16                               0.0
# ...                              ...
# 2244                             0.0
# 2245                             0.0
# 2247                             0.0
# 2252                             0.0
# 2255                             0.0
#
# [697 rows x 14 columns]

# %%
# Select all rows of columns ['STATE_NAME', 'DISTRICT_NAME', 'LENGTH_OF_ROAD_WORK_SANCTIONED_KM', 'COST_OF_WORKS_SANCTIONED_LAKHS']
PMGSY2_subset = PMGSY2[['STATE_NAME', 'DISTRICT_NAME', 'LENGTH_OF_ROAD_WORK_SANCTIONED_KM', 'COST_OF_WORKS_SANCTIONED_LAKHS']]
# Reset index
PMGSY2_subset.reset_index(drop=True, inplace=True)
PMGSY2_subset
# Out:
#          STATE_NAME          DISTRICT_NAME  LENGTH_OF_ROAD_WORK_SANCTIONED_KM  \
# 0    Andhra Pradesh  Alluri Sitharama Raju                             14.000
# 1    Andhra Pradesh              Anantapur                             75.020
# 2    Andhra Pradesh                Bapatla                             53.430
# 3    Andhra Pradesh                Kurnool                             65.660
# 4    Andhra Pradesh                Nandyal                             54.930
# ..              ...                    ...                                ...
# 692     West Bengal                Birbhum                             76.750
# 693     West Bengal                Hooghly                             96.426
# 694     West Bengal            Murshidabad                            162.946
# 695     West Bengal        Purba Medinipur                            101.850
# 696     West Bengal          Siliguri M.P.                             35.022
#
#      COST_OF_WORKS_SANCTIONED_LAKHS
# 0                           8.93850
# 1                          29.99530
# 2                          28.74360
# 3                          28.50850
# 4                          32.64160
# ..                              ...
# 692                        61.97305
# 693                        74.68126
# 694                       105.63891
# 695                        82.46289
# 696                        24.46831
#
# [697 rows x 4 columns]

# %%
# Combine the rows with the same distinct and state names by adding their corresponding column values
PMGSY2_subset = PMGSY2_subset.groupby(['STATE_NAME', 'DISTRICT_NAME']).sum().reset_index()
PMGSY2_subset
# Out:
#               STATE_NAME             DISTRICT_NAME  \
# 0    Andaman And Nicobar  North and Middle Andaman
# 1    Andaman And Nicobar             South Andaman
# 2         Andhra Pradesh     Alluri Sitharama Raju
# 3         Andhra Pradesh                Anakapalli
# 4         Andhra Pradesh                 Anantapur
# ..                   ...                       ...
# 692          West Bengal           Purba Medinipur
# 693          West Bengal                   Purulia
# 694          West Bengal             Siliguri M.P.
# 695          West Bengal         South 24-Parganas
# 696          West Bengal             Uttardinajpur
#
#      LENGTH_OF_ROAD_WORK_SANCTIONED_KM  COST_OF_WORKS_SANCTIONED_LAKHS
# 0                               54.670                        27.76460
# 1                               20.082                        10.40950
# 2                               14.000                         8.93850
# 3                               34.620                        21.30900
# 4                               75.020                        29.99530
# ..                                 ...                             ...
# 692                            101.850                        82.46289
# 693                            143.660                       112.21407
# 694                             35.022                        24.46831
# 695                            171.764                       148.82442
# 696                             81.437                        68.09995
#
# [697 rows x 4 columns]

# %% [markdown]
# ### PMGSY3_SCHEME

# %%
PMGSY3
# Out:
#              STATE_NAME      DISTRICT_NAME PMGSY_SCHEME  \
# 7        Andhra Pradesh          Anantapur    PMGSY-III
# 9        Andhra Pradesh          Annamayya    PMGSY-III
# 14       Andhra Pradesh           Kakinada    PMGSY-III
# 17       Andhra Pradesh            Nandyal    PMGSY-III
# 24    Arunachal Pradesh      Dibang Valley    PMGSY-III
# ...                 ...                ...          ...
# 2241        Uttarakhand        Rudraprayag    PMGSY-III
# 2242        Uttarakhand         Uttarkashi    PMGSY-III
# 2248        West Bengal              Nadia    PMGSY-III
# 2250        West Bengal  North 24 Parganas    PMGSY-III
# 2256        West Bengal  South 24-Parganas    PMGSY-III
#
#       NO_OF_ROAD_WORK_SANCTIONED  NO_OF_BRIDGES_SANCTIONED  \
# 7                             16                         5
# 9                             52                         1
# 14                            12                         1
# 17                            12                         3
# 24                             3                         3
# ...                          ...                       ...
# 2241                           7                         0
# 2242                          25                         0
# 2248                          24                         1
# 2250                          51                         0
# 2256                          47                         0
#
#       NO_OF_ROAD_WORKS_COMPLETED  NO_OF_BRIDGES_COMPLETED  \
# 7                             14                        0
# 9                             28                        0
# 14                             4                        0
# 17                            11                        1
# 24                             0                        0
# ...                          ...                      ...
# 2241                           0                        0
# 2242                           0                        0
# 2248                           7                        0
# 2250                           1                        0
# 2256                           2                        0
#
#       NO_OF_ROAD_WORKS_BALANCE  NO_OF_BRIDGES_BALANCE  \
# 7                            2                      5
# 9                           24                      1
# 14                           8                      1
# 17                           1                      2
# 24                           3                      3
# ...                        ...                    ...
# 2241                         7                      0
# 2242                        25                      0
# 2248                        17                      1
# 2250                        50                      0
# 2256                        45                      0
#
#       LENGTH_OF_ROAD_WORK_SANCTIONED_KM  COST_OF_WORKS_SANCTIONED_LAKHS  \
# 7                               145.623                       109.83990
# 9                               386.961                       222.36631
# 14                               87.620                        47.53970
# 17                              113.910                        87.63180
# 24                               26.200                        47.34870
# ...                                 ...                             ...
# 2241                             92.025                        86.61822
# 2242                            238.812                       206.92790
# 2248                            138.848                       106.38457
# 2250                            303.252                       215.07294
# 2256                            320.352                       226.43533
#
#       LENGTH_OF_ROAD_WORK_COMPLETED_KM  EXPENDITURE_OCCURED_LAKHS  \
# 7                              122.207                    68.1403
# 9                              199.515                   101.0857
# 14                              24.850                    10.6521
# 17                             101.894                    73.3457
# 24                               0.000                     1.1624
# ...                                ...                        ...
# 2241                            11.600                    13.6896
# 2242                             1.500                     3.4860
# 2248                            59.647                    30.9203
# 2250                            72.984                    35.4804
# 2256                            25.140                    18.2737
#
#       LENGTH_OF_ROAD_WORK_BALANCE_KM
# 7                             18.700
# 9                            181.581
# 14                            61.040
# 17                             6.500
# 24                            26.200
# ...                              ...
# 2241                          80.425
# 2242                         237.312
# 2248                          79.388
# 2250                         230.268
# 2256                         295.212
#
# [710 rows x 14 columns]

# %%
# Select all rows of columns ['STATE_NAME', 'DISTRICT_NAME', 'LENGTH_OF_ROAD_WORK_SANCTIONED_KM', 'COST_OF_WORKS_SANCTIONED_LAKHS']
PMGSY3_subset = PMGSY3[['STATE_NAME', 'DISTRICT_NAME', 'LENGTH_OF_ROAD_WORK_SANCTIONED_KM', 'COST_OF_WORKS_SANCTIONED_LAKHS']]
# Reset index
PMGSY3_subset.reset_index(drop=True, inplace=True)
PMGSY3_subset
# Out:
#             STATE_NAME      DISTRICT_NAME  LENGTH_OF_ROAD_WORK_SANCTIONED_KM  \
# 0       Andhra Pradesh          Anantapur                            145.623
# 1       Andhra Pradesh          Annamayya                            386.961
# 2       Andhra Pradesh           Kakinada                             87.620
# 3       Andhra Pradesh            Nandyal                            113.910
# 4    Arunachal Pradesh      Dibang Valley                             26.200
# ..                 ...                ...                                ...
# 705        Uttarakhand        Rudraprayag                             92.025
# 706        Uttarakhand         Uttarkashi                            238.812
# 707        West Bengal              Nadia                            138.848
# 708        West Bengal  North 24 Parganas                            303.252
# 709        West Bengal  South 24-Parganas                            320.352
#
#      COST_OF_WORKS_SANCTIONED_LAKHS
# 0                         109.83990
# 1                         222.36631
# 2                          47.53970
# 3                          87.63180
# 4                          47.34870
# ..                              ...
# 705                        86.61822
# 706                       206.92790
# 707                       106.38457
# 708                       215.07294
# 709                       226.43533
#
# [710 rows x 4 columns]

# %%
# Combine the rows with the same distinct and state names by adding their corresponding column values
PMGSY3_subset = PMGSY3_subset.groupby(['STATE_NAME', 'DISTRICT_NAME']).sum().reset_index()
PMGSY3_subset
# Out:
#          STATE_NAME          DISTRICT_NAME  LENGTH_OF_ROAD_WORK_SANCTIONED_KM  \
# 0    Andhra Pradesh  Alluri Sitharama Raju                             29.100
# 1    Andhra Pradesh             Anakapalli                             92.275
# 2    Andhra Pradesh              Anantapur                            145.623
# 3    Andhra Pradesh              Annamayya                            386.961
# 4    Andhra Pradesh                Bapatla                             82.069
# ..              ...                    ...                                ...
# 705     West Bengal        Purba Medinipur                            314.717
# 706     West Bengal                Purulia                            187.967
# 707     West Bengal          Siliguri M.P.                             44.827
# 708     West Bengal      South 24-Parganas                            320.352
# 709     West Bengal          Uttardinajpur                            158.926
#
#      COST_OF_WORKS_SANCTIONED_LAKHS
# 0                          15.62000
# 1                          60.77811
# 2                         109.83990
# 3                         222.36631
# 4                          87.31000
# ..                              ...
# 705                       240.26852
# 706                       114.75549
# 707                        28.08356
# 708                       226.43533
# 709                       110.28330
#
# [710 rows x 4 columns]

# %% [markdown]
# ### RCPLWEA Scheme

# %%
RCPLWEA
# Out:
#           STATE_NAME              DISTRICT_NAME PMGSY_SCHEME  \
# 13    Andhra Pradesh                   Kakinada      RCPLWEA
# 60             Bihar                      Banka      RCPLWEA
# 68             Bihar                     Nawada      RCPLWEA
# 73             Bihar                     Rohtas      RCPLWEA
# 87      Chhattisgarh                  Dantewada      RCPLWEA
# 100     Chhattisgarh                 Narayanpur      RCPLWEA
# 162        Jharkhand                      Gumla      RCPLWEA
# 297           Odisha                    Koraput      RCPLWEA
# 384        Telangana  Jayashankar Bhoopalapally      RCPLWEA
# 417    Uttar Pradesh                  Chandauli      RCPLWEA
# 472   Andhra Pradesh      Alluri Sitharama Raju      RCPLWEA
# 518            Bihar                 Lakhisarai      RCPLWEA
# 537     Chhattisgarh                    Bijapur      RCPLWEA
# 542     Chhattisgarh                     Kanker      RCPLWEA
# 561     Chhattisgarh                      Sukma      RCPLWEA
# 613        Jharkhand                     Chatra      RCPLWEA
# 615        Jharkhand                    Dhanbad      RCPLWEA
# 619        Jharkhand                 Hazaribagh      RCPLWEA
# 623        Jharkhand                    Koderma      RCPLWEA
# 629        Jharkhand        Pashchimi Singhbhum      RCPLWEA
# 631        Jharkhand                    Ramgarh      RCPLWEA
# 635        Jharkhand        Saraikela Kharsawan      RCPLWEA
# 637        Jharkhand                    Simdega      RCPLWEA
# 696      Maharashtra                 Gadchiroli      RCPLWEA
# 822        Telangana                 Mancherial      RCPLWEA
# 908   Andhra Pradesh       Parvathipuram Manyam      RCPLWEA
# 954            Bihar                      Jamui      RCPLWEA
# 1049       Jharkhand                    Giridih      RCPLWEA
# 1056       Jharkhand                    Latehar      RCPLWEA
# 1173          Odisha                  Kandhamal      RCPLWEA
# 1266       Telangana                     Mulugu      RCPLWEA
# 1320   Uttar Pradesh                 Sonebhadra      RCPLWEA
# 1410    Chhattisgarh                     Bastar      RCPLWEA
# 1420    Chhattisgarh                  Kondagaon      RCPLWEA
# 1423    Chhattisgarh                Rajnandgaon      RCPLWEA
# 1491       Jharkhand                  Lohardaga      RCPLWEA
# 1492       Jharkhand                     Palamu      RCPLWEA
# 1494       Jharkhand            Purbi Singhbhum      RCPLWEA
# 1496       Jharkhand                     Ranchi      RCPLWEA
# 1527  Madhya Pradesh                   Balaghat      RCPLWEA
# 1537  Madhya Pradesh                     Mandla      RCPLWEA
# 1795  Andhra Pradesh                 Srikakulam      RCPLWEA
# 1827           Bihar                 Aurangabad      RCPLWEA
# 1836           Bihar                       Gaya      RCPLWEA
# 1848           Bihar                Muzaffarpur      RCPLWEA
# 1925       Jharkhand                     Bokaro      RCPLWEA
# 1928       Jharkhand                      Dumka      RCPLWEA
# 1929       Jharkhand                     Garhwa      RCPLWEA
# 1933       Jharkhand                     Khunti      RCPLWEA
# 2020     Maharashtra                 Chandrapur      RCPLWEA
# 2076          Odisha                 Malkangiri      RCPLWEA
# 2080          Odisha                   Rayagada      RCPLWEA
# 2151       Telangana       Bhadradri Kothagudem      RCPLWEA
# 2153       Telangana       Komrambheem Asifabad      RCPLWEA
# 2155       Telangana                Mahabubabad      RCPLWEA
#
#       NO_OF_ROAD_WORK_SANCTIONED  NO_OF_BRIDGES_SANCTIONED  \
# 13                             3                         0
# 60                            11                        16
# 68                            17                        10
# 73                            22                         2
# 87                            17                         3
# 100                           10                         8
# 162                           17                        30
# 297                           19                         2
# 384                           11                         4
# 417                            7                         0
# 472                          124                        34
# 518                            1                         0
# 537                           17                         7
# 542                          124                        36
# 561                           46                         0
# 613                           17                         8
# 615                           16                         0
# 619                           14                         6
# 623                            1                         0
# 629                           31                        22
# 631                            6                         4
# 635                           15                         9
# 637                            5                         5
# 696                           26                        68
# 822                           21                        21
# 908                           55                        10
# 954                           22                        18
# 1049                          27                        15
# 1056                          27                        31
# 1173                           2                         0
# 1266                          52                        16
# 1320                          18                        11
# 1410                          51                         1
# 1420                          72                        11
# 1423                          54                        22
# 1491                          18                        14
# 1492                          14                        10
# 1494                           5                         2
# 1496                           1                         1
# 1527                          35                        43
# 1537                           2                         3
# 1795                          12                         1
# 1827                          29                        12
# 1836                          26                         8
# 1848                          25                        16
# 1925                          13                        12
# 1928                           9                         2
# 1929                          14                        23
# 1933                          53                        13
# 2020                          20                        44
# 2076                          30                         0
# 2080                           1                         0
# 2151                          30                        38
# 2153                          31                        33
# 2155                           1                         0
#
#       NO_OF_ROAD_WORKS_COMPLETED  NO_OF_BRIDGES_COMPLETED  \
# 13                             3                        0
# 60                            11                       16
# 68                            16                       10
# 73                            20                        2
# 87                            14                        2
# 100                            0                        1
# 162                           11                       26
# 297                           18                        0
# 384                            2                        2
# 417                            7                        0
# 472                           99                       21
# 518                            1                        0
# 537                            5                        1
# 542                           93                       14
# 561                           11                        0
# 613                           12                        6
# 615                           13                        0
# 619                           14                        6
# 623                            1                        0
# 629                           23                        9
# 631                            6                        3
# 635                           13                        7
# 637                            4                        3
# 696                           17                       51
# 822                            1                        6
# 908                           42                        7
# 954                           14                       18
# 1049                          22                       13
# 1056                           8                       19
# 1173                           0                        0
# 1266                           1                        5
# 1320                          13                       10
# 1410                          50                        1
# 1420                          64                        3
# 1423                          48                        5
# 1491                          11                        8
# 1492                           6                        7
# 1494                           1                        2
# 1496                           1                        0
# 1527                           3                       12
# 1537                           2                        3
# 1795                          10                        1
# 1827                          23                        9
# 1836                          20                        4
# 1848                          24                       12
# 1925                          13                        6
# 1928                           9                        2
# 1929                          12                       21
# 1933                          49                       13
# 2020                          20                       44
# 2076                          26                        0
# 2080                           1                        0
# 2151                           5                       15
# 2153                           6                        8
# 2155                           0                        0
#
#       NO_OF_ROAD_WORKS_BALANCE  NO_OF_BRIDGES_BALANCE  \
# 13                           0                      0
# 60                           0                      0
# 68                           1                      0
# 73                           2                      0
# 87                           3                      1
# 100                         10                      7
# 162                          6                      4
# 297                          1                      2
# 384                          9                      2
# 417                          0                      0
# 472                         25                     13
# 518                          0                      0
# 537                         12                      6
# 542                         31                     22
# 561                         35                      0
# 613                          5                      2
# 615                          3                      0
# 619                          0                      0
# 623                          0                      0
# 629                          8                     13
# 631                          0                      1
# 635                          2                      2
# 637                          1                      2
# 696                          9                     17
# 822                         20                     15
# 908                         13                      3
# 954                          8                      0
# 1049                         5                      2
# 1056                        19                     12
# 1173                         2                      0
# 1266                        51                     11
# 1320                         5                      1
# 1410                         1                      0
# 1420                         8                      8
# 1423                         6                     17
# 1491                         7                      6
# 1492                         8                      3
# 1494                         4                      0
# 1496                         0                      1
# 1527                        32                     31
# 1537                         0                      0
# 1795                         2                      0
# 1827                         6                      3
# 1836                         6                      4
# 1848                         1                      4
# 1925                         0                      6
# 1928                         0                      0
# 1929                         2                      2
# 1933                         4                      0
# 2020                         0                      0
# 2076                         4                      0
# 2080                         0                      0
# 2151                        25                     23
# 2153                        25                     25
# 2155                         1                      0
#
#       LENGTH_OF_ROAD_WORK_SANCTIONED_KM  COST_OF_WORKS_SANCTIONED_LAKHS  \
# 13                               19.470                        12.19000
# 60                              183.075                       272.19727
# 68                              217.440                       278.48476
# 73                               89.770                        97.69917
# 87                              156.525                       192.47540
# 100                             123.400                       117.13870
# 162                             264.960                       296.89745
# 297                             146.768                       140.64949
# 384                              78.700                        94.07464
# 417                              80.925                        45.63260
# 472                            1084.885                       827.64173
# 518                              16.415                        14.40069
# 537                             352.800                       292.68083
# 542                             690.725                       512.91634
# 561                             452.555                       257.60450
# 613                             179.710                       152.96067
# 615                              31.401                        24.43200
# 619                             123.328                       108.07188
# 623                              23.660                        17.68470
# 629                             302.715                       305.34461
# 631                              18.830                        33.04645
# 635                             131.527                       110.35551
# 637                              34.700                        49.00220
# 696                             487.716                       688.75014
# 822                             144.886                       220.61340
# 908                             385.484                       353.27394
# 954                             414.657                       549.95709
# 1049                            137.608                       130.42188
# 1056                            230.930                       268.15713
# 1173                             26.470                        21.52690
# 1266                            259.640                       308.80704
# 1320                            460.375                       363.03480
# 1410                            479.475                       303.27069
# 1420                            549.970                       392.95706
# 1423                            415.825                       308.05882
# 1491                            172.155                       173.70821
# 1492                            110.547                       141.31350
# 1494                             21.650                        29.89835
# 1496                              5.540                         8.21230
# 1527                            337.470                       477.24568
# 1537                              8.675                        13.00472
# 1795                             68.146                        54.85660
# 1827                            410.667                       434.77915
# 1836                            290.228                       299.64982
# 1848                            358.548                       521.57931
# 1925                             91.075                       110.99275
# 1928                             57.803                        48.79260
# 1929                            136.506                       150.98917
# 1933                            333.312                       316.83841
# 2020                            131.960                       194.26100
# 2076                            353.815                       314.24901
# 2080                              1.800                         1.29913
# 2151                            239.410                       331.14342
# 2153                            262.660                       407.15149
# 2155                             38.400                        37.04950
#
#       LENGTH_OF_ROAD_WORK_COMPLETED_KM  EXPENDITURE_OCCURED_LAKHS  \
# 13                              19.470                    10.7893
# 60                             181.293                   217.3813
# 68                             203.584                   211.7195
# 73                              85.905                    74.8447
# 87                             123.825                   102.2007
# 100                              7.000                    25.2453
# 162                            225.400                   265.6960
# 297                            140.469                   121.3137
# 384                             34.277                    51.4233
# 417                             80.550                    42.1013
# 472                            780.599                   490.0572
# 518                             16.415                    10.7907
# 537                             68.900                    51.8079
# 542                            529.829                   324.5423
# 561                            156.925                   118.5738
# 613                            139.455                   109.2739
# 615                             28.593                    20.7258
# 619                            123.328                    93.9569
# 623                             23.660                    21.5079
# 629                            246.445                   253.7802
# 631                             18.417                    31.1611
# 635                            128.097                   109.0983
# 637                             18.200                    32.8231
# 696                            409.401                   365.8335
# 822                             66.504                    92.4790
# 908                            305.191                   276.5407
# 954                            346.487                   438.0069
# 1049                           108.700                   104.7045
# 1056                           199.150                   199.2790
# 1173                             0.000                     5.6295
# 1266                           105.400                   120.1855
# 1320                           374.275                   281.1237
# 1410                           475.580                   201.4676
# 1420                           483.875                   268.1877
# 1423                           374.054                   208.9858
# 1491                           137.955                   133.6657
# 1492                            78.095                   121.6331
# 1494                            11.500                    19.0701
# 1496                             5.540                     7.6573
# 1527                            79.740                   245.4642
# 1537                             8.627                    12.7727
# 1795                            63.047                    49.2557
# 1827                           384.732                   412.7769
# 1836                           250.194                   228.2919
# 1848                           350.921                   529.8283
# 1925                            91.071                   100.2681
# 1928                            57.803                    43.3092
# 1929                           124.906                    92.3208
# 1933                           330.990                   299.9362
# 2020                           130.310                   160.3329
# 2076                           323.853                   282.6050
# 2080                             1.800                     1.3596
# 2151                           103.890                   118.3253
# 2153                           113.954                   127.0604
# 2155                            17.642                    15.1030
#
#       LENGTH_OF_ROAD_WORK_BALANCE_KM
# 13                             0.000
# 60                             0.000
# 68                             0.795
# 73                             3.625
# 87                            32.700
# 100                          116.400
# 162                           39.590
# 297                            5.087
# 384                           44.043
# 417                            0.000
# 472                          283.610
# 518                            0.000
# 537                          284.350
# 542                          155.815
# 561                          295.630
# 613                           40.430
# 615                            2.808
# 619                            0.000
# 623                            0.000
# 629                           54.579
# 631                            0.000
# 635                            3.430
# 637                           16.500
# 696                           78.315
# 822                           77.832
# 908                           74.084
# 954                           66.206
# 1049                          28.605
# 1056                          31.780
# 1173                          26.470
# 1266                         154.130
# 1320                          86.000
# 1410                           0.000
# 1420                          63.270
# 1423                          32.600
# 1491                          34.200
# 1492                          31.349
# 1494                          10.150
# 1496                           0.000
# 1527                         256.030
# 1537                           0.000
# 1795                           1.678
# 1827                          20.775
# 1836                          35.100
# 1848                           2.428
# 1925                           0.000
# 1928                           0.000
# 1929                          11.600
# 1933                           1.000
# 2020                           0.000
# 2076                          26.100
# 2080                           0.000
# 2151                         134.770
# 2153                         148.312
# 2155                          20.758

# %%
# Select all rows of columns ['STATE_NAME', 'DISTRICT_NAME', 'LENGTH_OF_ROAD_WORK_SANCTIONED_KM', 'COST_OF_WORKS_SANCTIONED_LAKHS']
RCPLWEA_subset = RCPLWEA[['STATE_NAME', 'DISTRICT_NAME', 'LENGTH_OF_ROAD_WORK_SANCTIONED_KM', 'COST_OF_WORKS_SANCTIONED_LAKHS']]
# Reset index
RCPLWEA_subset.reset_index(drop=True, inplace=True)
RCPLWEA_subset
# Out:
#         STATE_NAME              DISTRICT_NAME  \
# 0   Andhra Pradesh                   Kakinada
# 1            Bihar                      Banka
# 2            Bihar                     Nawada
# 3            Bihar                     Rohtas
# 4     Chhattisgarh                  Dantewada
# 5     Chhattisgarh                 Narayanpur
# 6        Jharkhand                      Gumla
# 7           Odisha                    Koraput
# 8        Telangana  Jayashankar Bhoopalapally
# 9    Uttar Pradesh                  Chandauli
# 10  Andhra Pradesh      Alluri Sitharama Raju
# 11           Bihar                 Lakhisarai
# 12    Chhattisgarh                    Bijapur
# 13    Chhattisgarh                     Kanker
# 14    Chhattisgarh                      Sukma
# 15       Jharkhand                     Chatra
# 16       Jharkhand                    Dhanbad
# 17       Jharkhand                 Hazaribagh
# 18       Jharkhand                    Koderma
# 19       Jharkhand        Pashchimi Singhbhum
# 20       Jharkhand                    Ramgarh
# 21       Jharkhand        Saraikela Kharsawan
# 22       Jharkhand                    Simdega
# 23     Maharashtra                 Gadchiroli
# 24       Telangana                 Mancherial
# 25  Andhra Pradesh       Parvathipuram Manyam
# 26           Bihar                      Jamui
# 27       Jharkhand                    Giridih
# 28       Jharkhand                    Latehar
# 29          Odisha                  Kandhamal
# 30       Telangana                     Mulugu
# 31   Uttar Pradesh                 Sonebhadra
# 32    Chhattisgarh                     Bastar
# 33    Chhattisgarh                  Kondagaon
# 34    Chhattisgarh                Rajnandgaon
# 35       Jharkhand                  Lohardaga
# 36       Jharkhand                     Palamu
# 37       Jharkhand            Purbi Singhbhum
# 38       Jharkhand                     Ranchi
# 39  Madhya Pradesh                   Balaghat
# 40  Madhya Pradesh                     Mandla
# 41  Andhra Pradesh                 Srikakulam
# 42           Bihar                 Aurangabad
# 43           Bihar                       Gaya
# 44           Bihar                Muzaffarpur
# 45       Jharkhand                     Bokaro
# 46       Jharkhand                      Dumka
# 47       Jharkhand                     Garhwa
# 48       Jharkhand                     Khunti
# 49     Maharashtra                 Chandrapur
# 50          Odisha                 Malkangiri
# 51          Odisha                   Rayagada
# 52       Telangana       Bhadradri Kothagudem
# 53       Telangana       Komrambheem Asifabad
# 54       Telangana                Mahabubabad
#
#     LENGTH_OF_ROAD_WORK_SANCTIONED_KM  COST_OF_WORKS_SANCTIONED_LAKHS
# 0                              19.470                        12.19000
# 1                             183.075                       272.19727
# 2                             217.440                       278.48476
# 3                              89.770                        97.69917
# 4                             156.525                       192.47540
# 5                             123.400                       117.13870
# 6                             264.960                       296.89745
# 7                             146.768                       140.64949
# 8                              78.700                        94.07464
# 9                              80.925                        45.63260
# 10                           1084.885                       827.64173
# 11                             16.415                        14.40069
# 12                            352.800                       292.68083
# 13                            690.725                       512.91634
# 14                            452.555                       257.60450
# 15                            179.710                       152.96067
# 16                             31.401                        24.43200
# 17                            123.328                       108.07188
# 18                             23.660                        17.68470
# 19                            302.715                       305.34461
# 20                             18.830                        33.04645
# 21                            131.527                       110.35551
# 22                             34.700                        49.00220
# 23                            487.716                       688.75014
# 24                            144.886                       220.61340
# 25                            385.484                       353.27394
# 26                            414.657                       549.95709
# 27                            137.608                       130.42188
# 28                            230.930                       268.15713
# 29                             26.470                        21.52690
# 30                            259.640                       308.80704
# 31                            460.375                       363.03480
# 32                            479.475                       303.27069
# 33                            549.970                       392.95706
# 34                            415.825                       308.05882
# 35                            172.155                       173.70821
# 36                            110.547                       141.31350
# 37                             21.650                        29.89835
# 38                              5.540                         8.21230
# 39                            337.470                       477.24568
# 40                              8.675                        13.00472
# 41                             68.146                        54.85660
# 42                            410.667                       434.77915
# 43                            290.228                       299.64982
# 44                            358.548                       521.57931
# 45                             91.075                       110.99275
# 46                             57.803                        48.79260
# 47                            136.506                       150.98917
# 48                            333.312                       316.83841
# 49                            131.960                       194.26100
# 50                            353.815                       314.24901
# 51                              1.800                         1.29913
# 52                            239.410                       331.14342
# 53                            262.660                       407.15149
# 54                             38.400                        37.04950

# %%
# Combine the rows with the same distinct and state names by adding their corresponding column values
RCPLWEA_subset = RCPLWEA_subset.groupby(['STATE_NAME', 'DISTRICT_NAME']).sum().reset_index()
RCPLWEA_subset
# Out:
#         STATE_NAME              DISTRICT_NAME  \
# 0   Andhra Pradesh      Alluri Sitharama Raju
# 1   Andhra Pradesh                   Kakinada
# 2   Andhra Pradesh       Parvathipuram Manyam
# 3   Andhra Pradesh                 Srikakulam
# 4            Bihar                 Aurangabad
# 5            Bihar                      Banka
# 6            Bihar                       Gaya
# 7            Bihar                      Jamui
# 8            Bihar                 Lakhisarai
# 9            Bihar                Muzaffarpur
# 10           Bihar                     Nawada
# 11           Bihar                     Rohtas
# 12    Chhattisgarh                     Bastar
# 13    Chhattisgarh                    Bijapur
# 14    Chhattisgarh                  Dantewada
# 15    Chhattisgarh                     Kanker
# 16    Chhattisgarh                  Kondagaon
# 17    Chhattisgarh                 Narayanpur
# 18    Chhattisgarh                Rajnandgaon
# 19    Chhattisgarh                      Sukma
# 20       Jharkhand                     Bokaro
# 21       Jharkhand                     Chatra
# 22       Jharkhand                    Dhanbad
# 23       Jharkhand                      Dumka
# 24       Jharkhand                     Garhwa
# 25       Jharkhand                    Giridih
# 26       Jharkhand                      Gumla
# 27       Jharkhand                 Hazaribagh
# 28       Jharkhand                     Khunti
# 29       Jharkhand                    Koderma
# 30       Jharkhand                    Latehar
# 31       Jharkhand                  Lohardaga
# 32       Jharkhand                     Palamu
# 33       Jharkhand        Pashchimi Singhbhum
# 34       Jharkhand            Purbi Singhbhum
# 35       Jharkhand                    Ramgarh
# 36       Jharkhand                     Ranchi
# 37       Jharkhand        Saraikela Kharsawan
# 38       Jharkhand                    Simdega
# 39  Madhya Pradesh                   Balaghat
# 40  Madhya Pradesh                     Mandla
# 41     Maharashtra                 Chandrapur
# 42     Maharashtra                 Gadchiroli
# 43          Odisha                  Kandhamal
# 44          Odisha                    Koraput
# 45          Odisha                 Malkangiri
# 46          Odisha                   Rayagada
# 47       Telangana       Bhadradri Kothagudem
# 48       Telangana  Jayashankar Bhoopalapally
# 49       Telangana       Komrambheem Asifabad
# 50       Telangana                Mahabubabad
# 51       Telangana                 Mancherial
# 52       Telangana                     Mulugu
# 53   Uttar Pradesh                  Chandauli
# 54   Uttar Pradesh                 Sonebhadra
#
#     LENGTH_OF_ROAD_WORK_SANCTIONED_KM  COST_OF_WORKS_SANCTIONED_LAKHS
# 0                            1084.885                       827.64173
# 1                              19.470                        12.19000
# 2                             385.484                       353.27394
# 3                              68.146                        54.85660
# 4                             410.667                       434.77915
# 5                             183.075                       272.19727
# 6                             290.228                       299.64982
# 7                             414.657                       549.95709
# 8                              16.415                        14.40069
# 9                             358.548                       521.57931
# 10                            217.440                       278.48476
# 11                             89.770                        97.69917
# 12                            479.475                       303.27069
# 13                            352.800                       292.68083
# 14                            156.525                       192.47540
# 15                            690.725                       512.91634
# 16                            549.970                       392.95706
# 17                            123.400                       117.13870
# 18                            415.825                       308.05882
# 19                            452.555                       257.60450
# 20                             91.075                       110.99275
# 21                            179.710                       152.96067
# 22                             31.401                        24.43200
# 23                             57.803                        48.79260
# 24                            136.506                       150.98917
# 25                            137.608                       130.42188
# 26                            264.960                       296.89745
# 27                            123.328                       108.07188
# 28                            333.312                       316.83841
# 29                             23.660                        17.68470
# 30                            230.930                       268.15713
# 31                            172.155                       173.70821
# 32                            110.547                       141.31350
# 33                            302.715                       305.34461
# 34                             21.650                        29.89835
# 35                             18.830                        33.04645
# 36                              5.540                         8.21230
# 37                            131.527                       110.35551
# 38                             34.700                        49.00220
# 39                            337.470                       477.24568
# 40                              8.675                        13.00472
# 41                            131.960                       194.26100
# 42                            487.716                       688.75014
# 43                             26.470                        21.52690
# 44                            146.768                       140.64949
# 45                            353.815                       314.24901
# 46                              1.800                         1.29913
# 47                            239.410                       331.14342
# 48                             78.700                        94.07464
# 49                            262.660                       407.15149
# 50                             38.400                        37.04950
# 51                            144.886                       220.61340
# 52                            259.640                       308.80704
# 53                             80.925                        45.63260
# 54                            460.375                       363.03480

# %% [markdown]
# ### PMGSY-JANMAN Scheme

# %%
PMGSY_JANMAN
# Out:
#           STATE_NAME  DISTRICT_NAME PMGSY_SCHEME  NO_OF_ROAD_WORK_SANCTIONED  \
# 18    Andhra Pradesh        Nandyal    PM-JANMAN                           1
# 82      Chhattisgarh      Balrampur    PM-JANMAN                         113
# 85      Chhattisgarh       Bilaspur    PM-JANMAN                          32
# 92      Chhattisgarh        Jashpur    PM-JANMAN                          80
# 120          Gujarat    Sabarkantha    PM-JANMAN                           2
# ...              ...            ...          ...                         ...
# 2012  Madhya Pradesh          Sidhi    PM-JANMAN                          44
# 2082          Odisha     Sundargarh    PM-JANMAN                           2
# 2180         Tripura         Gomati    PM-JANMAN                          19
# 2182         Tripura  North Tripura    PM-JANMAN                           8
# 2185         Tripura        Unakoti    PM-JANMAN                           3
#
#       NO_OF_BRIDGES_SANCTIONED  NO_OF_ROAD_WORKS_COMPLETED  \
# 18                           0                           0
# 82                           0                           0
# 85                           0                           0
# 92                           0                           0
# 120                          0                           0
# ...                        ...                         ...
# 2012                         0                           0
# 2082                         0                           0
# 2180                         0                           0
# 2182                         0                           0
# 2185                         0                           0
#
#       NO_OF_BRIDGES_COMPLETED  NO_OF_ROAD_WORKS_BALANCE  \
# 18                          0                         1
# 82                          0                       113
# 85                          0                        32
# 92                          0                        80
# 120                         0                         2
# ...                       ...                       ...
# 2012                        0                        44
# 2082                        0                         2
# 2180                        0                        19
# 2182                        0                         8
# 2185                        0                         3
#
#       NO_OF_BRIDGES_BALANCE  LENGTH_OF_ROAD_WORK_SANCTIONED_KM  \
# 18                        0                              7.110
# 82                        0                            374.630
# 85                        0                            126.550
# 92                        0                            281.250
# 120                       0                              1.550
# ...                     ...                                ...
# 2012                      0                            145.839
# 2082                      0                              2.200
# 2180                      0                             26.438
# 2182                      0                             35.027
# 2185                      0                             10.271
#
#       COST_OF_WORKS_SANCTIONED_LAKHS  LENGTH_OF_ROAD_WORK_COMPLETED_KM  \
# 18                           4.40000                               0.0
# 82                         245.18930                               0.0
# 85                          91.39231                               1.2
# 92                         214.87552                               0.0
# 120                          1.24290                               0.0
# ...                              ...                               ...
# 2012                       106.85660                               0.0
# 2082                         2.08580                               0.0
# 2180                        27.58798                               0.0
# 2182                        32.35566                               0.0
# 2185                         9.92230                               0.0
#
#       EXPENDITURE_OCCURED_LAKHS  LENGTH_OF_ROAD_WORK_BALANCE_KM
# 18                          0.0                           7.110
# 82                          0.0                         374.630
# 85                          0.0                         125.350
# 92                          0.0                         281.250
# 120                         0.0                           1.550
# ...                         ...                             ...
# 2012                        0.0                         145.839
# 2082                        0.0                           2.200
# 2180                        0.0                          26.438
# 2182                        0.0                          35.027
# 2185                        0.0                          10.271
#
# [74 rows x 14 columns]

# %%
# Select all rows of columns ['STATE_NAME', 'DISTRICT_NAME', 'LENGTH_OF_ROAD_WORK_SANCTIONED_KM', 'COST_OF_WORKS_SANCTIONED_LAKHS']
PMGSY_JANMAN_subset = PMGSY_JANMAN[['STATE_NAME', 'DISTRICT_NAME', 'LENGTH_OF_ROAD_WORK_SANCTIONED_KM', 'COST_OF_WORKS_SANCTIONED_LAKHS']]
# Reset index
PMGSY_JANMAN_subset.reset_index(drop=True, inplace=True)
PMGSY_JANMAN_subset
# Out:
#         STATE_NAME  DISTRICT_NAME  LENGTH_OF_ROAD_WORK_SANCTIONED_KM  \
# 0   Andhra Pradesh        Nandyal                              7.110
# 1     Chhattisgarh      Balrampur                            374.630
# 2     Chhattisgarh       Bilaspur                            126.550
# 3     Chhattisgarh        Jashpur                            281.250
# 4          Gujarat    Sabarkantha                              1.550
# ..             ...            ...                                ...
# 69  Madhya Pradesh          Sidhi                            145.839
# 70          Odisha     Sundargarh                              2.200
# 71         Tripura         Gomati                             26.438
# 72         Tripura  North Tripura                             35.027
# 73         Tripura        Unakoti                             10.271
#
#     COST_OF_WORKS_SANCTIONED_LAKHS
# 0                          4.40000
# 1                        245.18930
# 2                         91.39231
# 3                        214.87552
# 4                          1.24290
# ..                             ...
# 69                       106.85660
# 70                         2.08580
# 71                        27.58798
# 72                        32.35566
# 73                         9.92230
#
# [74 rows x 4 columns]

# %%
# Combine the rows with the same distinct and state names by adding their corresponding column values
PMGSY_JANMAN_subset = PMGSY_JANMAN_subset.groupby(['STATE_NAME', 'DISTRICT_NAME']).sum().reset_index()
PMGSY_JANMAN_subset
# Out:
#         STATE_NAME          DISTRICT_NAME  LENGTH_OF_ROAD_WORK_SANCTIONED_KM  \
# 0   Andhra Pradesh  Alluri Sitharama Raju                            483.640
# 1   Andhra Pradesh                  Eluru                             34.868
# 2   Andhra Pradesh               Kakinada                             19.150
# 3   Andhra Pradesh                Nandyal                              7.110
# 4   Andhra Pradesh   Parvathipuram Manyam                             38.650
# ..             ...                    ...                                ...
# 69         Tripura                 Gomati                             26.438
# 70         Tripura                 Khowai                              3.033
# 71         Tripura          North Tripura                             35.027
# 72         Tripura          South Tripura                              3.715
# 73         Tripura                Unakoti                             10.271
#
#     COST_OF_WORKS_SANCTIONED_LAKHS
# 0                        442.64179
# 1                         26.36000
# 2                         16.10300
# 3                          4.40000
# 4                         39.56477
# ..                             ...
# 69                        27.58798
# 70                         2.88640
# 71                        32.35566
# 72                         3.69646
# 73                         9.92230
#
# [74 rows x 4 columns]

# %% [markdown]
# ## TB_Lab

# %%
TB_Lab
# Out:
#           State/UT Unnamed: 1  \
# 0   Andhra Pradesh     Public
# 1   Andhra Pradesh     Public
# 2   Andhra Pradesh     Public
# 3   Andhra Pradesh     Public
# 4            Assam     Public
# ..             ...        ...
# 92      Tamil Nadu    Private
# 93   Uttar Pradesh    Private
# 94   Uttar Pradesh    Private
# 95     West Bengal    Private
# 96     West Bengal    Private
#
#                  Name of the Culture & DST Laboratory Liquid culture  \
# 0                                   IRL, Visakhaptnam      Available
# 1                   C&DST Laboratory, SMC, Vijayawada      Available
# 2            C&DST Laboratory, DTRC(DFIT),Nellore,A.P  Not Available
# 3        C&DST Laboratory, RDT Hospital, Bathalapalli      Available
# 4                                        IRL Guwahati      Available
# ..                                                ...            ...
# 92  Vision Research Fondation laboratory, Shakar N...      Available
# 93                   Subharti Medical College, Meerut  Not Available
# 94       Shri Ram Murti Smarak Institutions, Bareilly      Available
# 95                           SRL Diagnsotics, Kolkata      Available
# 96                   AMRI Hospital, Dhakuria, Kolkata      Available
#
#          FL LCDST       SL LCDST         FL LPA         SL LPA
# 0       Certified      Certified      Certified      Certified
# 1   Not Certified  Not Certified  Not Certified  Not Certified
# 2   Not Certified  Not Certified      Certified      Certified
# 3       Certified  Not Certified      Certified      Certified
# 4       Certified      Certified      Certified      Certified
# ..            ...            ...            ...            ...
# 92      Certified  Not Certified  Not Certified  Not Certified
# 93  Not Certified  Not Certified      Certified  Not Certified
# 94  Not Certified  Not Certified  Not Certified  Not Certified
# 95      Certified  Not Certified  Not Certified  Not Certified
# 96  Not Certified  Not Certified  Not Certified  Not Certified
#
# [97 rows x 8 columns]

# %%
TB_Lab.columns
# Out:
# Index(['State/UT', 'Unnamed: 1', 'Name of the Culture & DST Laboratory',
#        'Liquid culture', 'FL LCDST', 'SL LCDST', 'FL LPA', 'SL LPA'],
#       dtype='object')

# %%
TB_Lab_subset = TB_Lab[['State/UT', 'Unnamed: 1', 'Liquid culture', 'FL LCDST', 'SL LCDST', 'FL LPA', 'SL LPA']].copy()
# Rename 'Unnamed: 1' to 'Public/Private'
TB_Lab_subset.rename(columns={'Unnamed: 1': 'Public/Private'}, inplace=True)
TB_Lab_subset
# Out:
#           State/UT Public/Private Liquid culture       FL LCDST  \
# 0   Andhra Pradesh         Public      Available      Certified
# 1   Andhra Pradesh         Public      Available  Not Certified
# 2   Andhra Pradesh         Public  Not Available  Not Certified
# 3   Andhra Pradesh         Public      Available      Certified
# 4            Assam         Public      Available      Certified
# ..             ...            ...            ...            ...
# 92      Tamil Nadu        Private      Available      Certified
# 93   Uttar Pradesh        Private  Not Available  Not Certified
# 94   Uttar Pradesh        Private      Available  Not Certified
# 95     West Bengal        Private      Available      Certified
# 96     West Bengal        Private      Available  Not Certified
#
#          SL LCDST         FL LPA         SL LPA
# 0       Certified      Certified      Certified
# 1   Not Certified  Not Certified  Not Certified
# 2   Not Certified      Certified      Certified
# 3   Not Certified      Certified      Certified
# 4       Certified      Certified      Certified
# ..            ...            ...            ...
# 92  Not Certified  Not Certified  Not Certified
# 93  Not Certified      Certified  Not Certified
# 94  Not Certified  Not Certified  Not Certified
# 95  Not Certified  Not Certified  Not Certified
# 96  Not Certified  Not Certified  Not Certified
#
# [97 rows x 7 columns]

# %%
# Convert the TB_Lab_subset to numerical
TB_Lab_subset['Public/Private'] = TB_Lab_subset['Public/Private'].apply(lambda x: 1 if x == 'Public' else 0)
TB_Lab_subset['Liquid culture'] = TB_Lab_subset['Liquid culture'].apply(lambda x: 1 if x == 'Available' else 0)
TB_Lab_subset['FL LCDST'] = TB_Lab_subset['FL LCDST'].apply(lambda x: 1 if x == 'Certified' else 0)
TB_Lab_subset['SL LCDST'] = TB_Lab_subset['SL LCDST'].apply(lambda x: 1 if x == 'Certified' else 0)
TB_Lab_subset['FL LPA'] = TB_Lab_subset['FL LPA'].apply(lambda x: 1 if x == 'Certified' else 0)
TB_Lab_subset['SL LPA'] = TB_Lab_subset['SL LPA'].apply(lambda x: 1 if x == 'Certified' else 0)

TB_Lab_subset
# Out:
#           State/UT  Public/Private  Liquid culture  FL LCDST  SL LCDST  \
# 0   Andhra Pradesh               1               1         1         1
# 1   Andhra Pradesh               1               1         0         0
# 2   Andhra Pradesh               1               0         0         0
# 3   Andhra Pradesh               1               1         1         0
# 4            Assam               1               1         1         1
# ..             ...             ...             ...       ...       ...
# 92      Tamil Nadu               0               1         1         0
# 93   Uttar Pradesh               0               0         0         0
# 94   Uttar Pradesh               0               1         0         0
# 95     West Bengal               0               1         1         0
# 96     West Bengal               0               1         0         0
#
#     FL LPA  SL LPA
# 0        1       1
# 1        0       0
# 2        1       1
# 3        1       1
# 4        1       1
# ..     ...     ...
# 92       0       0
# 93       1       0
# 94       0       0
# 95       0       0
# 96       0       0
#
# [97 rows x 7 columns]

# %%
# Combine the rows of all the columns based on the State/UT values
TB_Lab_subset = TB_Lab_subset.groupby('State/UT').sum().reset_index()
TB_Lab_subset
# Out:
#             State/UT  Public/Private  Liquid culture  FL LCDST  SL LCDST  \
# 0     Andhra Pradesh               4               3         2         1
# 1              Assam               1               1         1         1
# 2              Bihar               4               4         3         2
# 3         Chandigarh               1               1         1         1
# 4       Chhattisgarh               2               1         1         1
# 5              Delhi               4               4         4         3
# 6                Goa               1               1         1         1
# 7            Gujarat               3               3         3         3
# 8            Haryana               2               2         0         0
# 9   Himachal Pradesh               2               1         0         0
# 10   Jammu & Kashmir               1               0         0         0
# 11         Jharkhand               1               1         1         1
# 12         Karnataka               4               4         4         4
# 13            Kerala               2               2         1         1
# 14    Madhya Pradesh               6               5         4         3
# 15       Maharashtra               8              13        13        12
# 16           Manipur               0               1         0         0
# 17         Meghalaya               0               0         0         0
# 18            Odisha               2               2         2         2
# 19        Puducherry               1               1         1         1
# 20            Punjab               2               2         1         1
# 21         Rajasthan               4               3         3         2
# 22            Sikkim               1               1         1         0
# 23        Tamil Nadu               6               8         6         5
# 24         Telangana               3               3         2         2
# 25           Tripura               1               1         1         0
# 26     Uttar Pradesh               9               8         5         4
# 27       Uttarakhand               1               0         0         0
# 28       West Bengal               4               6         3         2
#
#     FL LPA  SL LPA
# 0        3       3
# 1        1       1
# 2        3       3
# 3        1       1
# 4        2       2
# 5        3       3
# 6        1       1
# 7        4       2
# 8        2       2
# 9        1       1
# 10       1       1
# 11       1       1
# 12       5       4
# 13       2       2
# 14       6       6
# 15      12       9
# 16       0       0
# 17       1       1
# 18       2       2
# 19       1       1
# 20       1       1
# 21       4       4
# 22       1       1
# 23       7       7
# 24       2       2
# 25       1       1
# 26       9       5
# 27       1       1
# 28       4       4

# %% [markdown]
# # Combining all the datasets together

# %% [markdown]
# Assumption: For the numerical values, if the dataset is at the state-level, then we divide the value equally among the state districts. While for the categorical values, we allocate same class for all the districts of that state.

# %%
import pandas as pd

def combine_datasets(table1: pd.DataFrame, table2: pd.DataFrame):
    unmatched_combinations = set()

    # Scenario 1: Both 'state_name' and 'district_name' are present in table2
    if 'state_name' in table2.columns and 'district_name' in table2.columns:
        for _, row in table2.iterrows():
            state_name, district_name = row['state_name'], row['district_name']
            match = table1[(table1['state_name'] == state_name) & (table1['district_name'] == district_name)]

            if not match.empty:
                # Update the matched row in table1
                for col in table2.columns:
                    if col not in ['state_name', 'district_name']:
                        table1.loc[match.index, col] = row[col]
            else:
                # Add to unmatched combinations and append the row to table1
                unmatched_combinations.add((state_name, district_name))
                table1 = pd.concat([table1, pd.DataFrame([row])], ignore_index=True)

        # Sort table1 by 'state_name' and 'district_name'
        table1 = table1.sort_values(by=['state_name', 'district_name']).reset_index(drop=True)
        return table1, unmatched_combinations

    # Scenario 2: Only 'state_name' is present in table2
    elif 'state_name' in table2.columns:
        updated_table2 = table1.copy()
        for _, row in table2.iterrows():
            state_name = row['state_name']
            state_districts = table1[table1['state_name'] == state_name]

            if not state_districts.empty:
                for col in table2.columns:
                    if col != 'state_name':
                        if pd.api.types.is_numeric_dtype(table2[col]):  # Check column dtype in table2, not row
                            # Divide numerical feature among districts
                            divided_value = row[col] / len(state_districts)
                            updated_table2.loc[state_districts.index, col] = divided_value
                        else:
                            # Copy categorical value to all districts
                            updated_table2.loc[state_districts.index, col] = row[col]
            else:
                # Add to unmatched state_names and append the row to table2
                unmatched_combinations.add(state_name)
                updated_table2 = pd.concat([updated_table2, pd.DataFrame([row])], ignore_index=True)

        # Sort updated_table2 by 'state_name' and 'district_name'
        updated_table2 = updated_table2.sort_values(by=['state_name', 'district_name']).reset_index(drop=True)
        return updated_table2, unmatched_combinations

    else:
        raise ValueError("The required columns are not present in table2.")

# %%
# rename column 'total_beneficiaries' to 'total_beneficiaries_<scheme_name>'
IGNOAPS_subset = IGNOAPS_subset.rename(columns={'total_beneficiaries': 'total_beneficiaries_IGNOAPS'})
IGNDPS_subset.rename(columns={'total_beneficiaries': 'total_beneficiaries_IGNDPS'}, inplace=True)
IGNWPS_subset.rename(columns={'total_beneficiaries': 'total_beneficiaries_IGNWPS'}, inplace=True)

dataset = IGNOAPS_subset.copy()
dataset
# Out:
#               state_name             district_name  \
# 0    ANDAMAN AND NICOBAR                  NICOBARS
# 1    ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR            SOUTH ANDAMANS
# 3         ANDHRA PRADESH                 ANANTAPUR
# 4         ANDHRA PRADESH     Alluri Sitharama Raju
# ..                   ...                       ...
# 728          WEST BENGAL           PASCHIM BURDWAN
# 729          WEST BENGAL         PASCHIM MEDINIPUR
# 730          WEST BENGAL             PURBA BURDWAN
# 731          WEST BENGAL           PURBA MEDINIPUR
# 732          WEST BENGAL                   PURULIA
#
#      total_beneficiaries_IGNOAPS
# 0                           9404
# 1                          13874
# 2                          14181
# 3                        2659988
# 4                         165552
# ..                           ...
# 728                       104736
# 729                      1079448
# 730                      1224987
# 731                       892569
# 732                       836504
#
# [733 rows x 3 columns]

# %%
combined_dataset, unmatched_combinations = combine_datasets(dataset, IGNDPS_subset)
print('Unmatched Combinations:', unmatched_combinations)
combined_dataset
# Out:
# Unmatched Combinations: set()
#               state_name             district_name  \
# 0    ANDAMAN AND NICOBAR                  NICOBARS
# 1    ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR            SOUTH ANDAMANS
# 3         ANDHRA PRADESH                 ANANTAPUR
# 4         ANDHRA PRADESH     Alluri Sitharama Raju
# ..                   ...                       ...
# 728          WEST BENGAL           PASCHIM BURDWAN
# 729          WEST BENGAL         PASCHIM MEDINIPUR
# 730          WEST BENGAL             PURBA BURDWAN
# 731          WEST BENGAL           PURBA MEDINIPUR
# 732          WEST BENGAL                   PURULIA
#
#      total_beneficiaries_IGNOAPS  total_beneficiaries_IGNDPS
# 0                           9404                       150.0
# 1                          13874                      1780.0
# 2                          14181                       766.0
# 3                        2659988                     88709.0
# 4                         165552                         NaN
# ..                           ...                         ...
# 728                       104736                      1061.0
# 729                      1079448                     60250.0
# 730                      1224987                     49714.0
# 731                       892569                     72783.0
# 732                       836504                     28929.0
#
# [733 rows x 4 columns]

# %%
# Replace missing values with 0
combined_dataset.fillna(0, inplace=True)
combined_dataset
# Out:
#               state_name             district_name  \
# 0    ANDAMAN AND NICOBAR                  NICOBARS
# 1    ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR            SOUTH ANDAMANS
# 3         ANDHRA PRADESH                 ANANTAPUR
# 4         ANDHRA PRADESH     Alluri Sitharama Raju
# ..                   ...                       ...
# 728          WEST BENGAL           PASCHIM BURDWAN
# 729          WEST BENGAL         PASCHIM MEDINIPUR
# 730          WEST BENGAL             PURBA BURDWAN
# 731          WEST BENGAL           PURBA MEDINIPUR
# 732          WEST BENGAL                   PURULIA
#
#      total_beneficiaries_IGNOAPS  total_beneficiaries_IGNDPS
# 0                           9404                       150.0
# 1                          13874                      1780.0
# 2                          14181                       766.0
# 3                        2659988                     88709.0
# 4                         165552                         0.0
# ..                           ...                         ...
# 728                       104736                      1061.0
# 729                      1079448                     60250.0
# 730                      1224987                     49714.0
# 731                       892569                     72783.0
# 732                       836504                     28929.0
#
# [733 rows x 4 columns]

# %%
combine_dataset, unmatched_combinations = combine_datasets(combined_dataset, IGNWPS_subset)
print('Unmatched Combinations:', unmatched_combinations)
combine_dataset
# Out:
# Unmatched Combinations: set()
#               state_name             district_name  \
# 0    ANDAMAN AND NICOBAR                  NICOBARS
# 1    ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR            SOUTH ANDAMANS
# 3         ANDHRA PRADESH                 ANANTAPUR
# 4         ANDHRA PRADESH     Alluri Sitharama Raju
# ..                   ...                       ...
# 728          WEST BENGAL           PASCHIM BURDWAN
# 729          WEST BENGAL         PASCHIM MEDINIPUR
# 730          WEST BENGAL             PURBA BURDWAN
# 731          WEST BENGAL           PURBA MEDINIPUR
# 732          WEST BENGAL                   PURULIA
#
#      total_beneficiaries_IGNOAPS  total_beneficiaries_IGNDPS  \
# 0                           9404                       150.0
# 1                          13874                      1780.0
# 2                          14181                       766.0
# 3                        2659988                     88709.0
# 4                         165552                         0.0
# ..                           ...                         ...
# 728                       104736                      1061.0
# 729                      1079448                     60250.0
# 730                      1224987                     49714.0
# 731                       892569                     72783.0
# 732                       836504                     28929.0
#
#      total_beneficiaries_IGNWPS
# 0                        2290.0
# 1                        3660.0
# 2                        2014.0
# 3                      799621.0
# 4                       79096.0
# ..                          ...
# 728                    139257.0
# 729                    838762.0
# 730                   1165481.0
# 731                    580736.0
# 732                    395344.0
#
# [733 rows x 5 columns]

# %%
# Replace missing values with 0
combine_dataset.fillna(0, inplace=True)
combine_dataset
# Out:
#               state_name             district_name  \
# 0    ANDAMAN AND NICOBAR                  NICOBARS
# 1    ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR            SOUTH ANDAMANS
# 3         ANDHRA PRADESH                 ANANTAPUR
# 4         ANDHRA PRADESH     Alluri Sitharama Raju
# ..                   ...                       ...
# 728          WEST BENGAL           PASCHIM BURDWAN
# 729          WEST BENGAL         PASCHIM MEDINIPUR
# 730          WEST BENGAL             PURBA BURDWAN
# 731          WEST BENGAL           PURBA MEDINIPUR
# 732          WEST BENGAL                   PURULIA
#
#      total_beneficiaries_IGNOAPS  total_beneficiaries_IGNDPS  \
# 0                           9404                       150.0
# 1                          13874                      1780.0
# 2                          14181                       766.0
# 3                        2659988                     88709.0
# 4                         165552                         0.0
# ..                           ...                         ...
# 728                       104736                      1061.0
# 729                      1079448                     60250.0
# 730                      1224987                     49714.0
# 731                       892569                     72783.0
# 732                       836504                     28929.0
#
#      total_beneficiaries_IGNWPS
# 0                        2290.0
# 1                        3660.0
# 2                        2014.0
# 3                      799621.0
# 4                       79096.0
# ..                          ...
# 728                    139257.0
# 729                    838762.0
# 730                   1165481.0
# 731                    580736.0
# 732                    395344.0
#
# [733 rows x 5 columns]

# %%
combined_dataset, unmatched_combinations = combine_datasets(combined_dataset, DHIS_subset)
print('Unmatched Combinations:', unmatched_combinations)
combined_dataset
# Out:
# Unmatched Combinations: set()
#               state_name             district_name  \
# 0    ANDAMAN AND NICOBAR                  NICOBARS
# 1    ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR            SOUTH ANDAMANS
# 3         ANDHRA PRADESH                 ANANTAPUR
# 4         ANDHRA PRADESH     Alluri Sitharama Raju
# ..                   ...                       ...
# 728          WEST BENGAL           PASCHIM BURDWAN
# 729          WEST BENGAL         PASCHIM MEDINIPUR
# 730          WEST BENGAL             PURBA BURDWAN
# 731          WEST BENGAL           PURBA MEDINIPUR
# 732          WEST BENGAL                   PURULIA
#
#      total_beneficiaries_IGNOAPS  total_beneficiaries_IGNDPS  \
# 0                           9404                       150.0
# 1                          13874                      1780.0
# 2                          14181                       766.0
# 3                        2659988                     88709.0
# 4                         165552                         0.0
# ..                           ...                         ...
# 728                       104736                      1061.0
# 729                      1079448                     60250.0
# 730                      1224987                     49714.0
# 731                       892569                     72783.0
# 732                       836504                     28929.0
#
#      total_beneficiaries_IGNWPS  Funds_Released_DHBS
# 0                        2290.0                  NaN
# 1                        3660.0                  NaN
# 2                        2014.0                  NaN
# 3                      799621.0             0.187200
# 4                       79096.0             0.187200
# ..                          ...                  ...
# 728                    139257.0             0.008261
# 729                    838762.0             0.008261
# 730                   1165481.0             0.008261
# 731                    580736.0             0.008261
# 732                    395344.0             0.008261
#
# [733 rows x 6 columns]

# %%
# Replace the missing values with 0
combined_dataset.fillna(0, inplace=True)
combined_dataset
# Out:
#               state_name             district_name  \
# 0    ANDAMAN AND NICOBAR                  NICOBARS
# 1    ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR            SOUTH ANDAMANS
# 3         ANDHRA PRADESH                 ANANTAPUR
# 4         ANDHRA PRADESH     Alluri Sitharama Raju
# ..                   ...                       ...
# 728          WEST BENGAL           PASCHIM BURDWAN
# 729          WEST BENGAL         PASCHIM MEDINIPUR
# 730          WEST BENGAL             PURBA BURDWAN
# 731          WEST BENGAL           PURBA MEDINIPUR
# 732          WEST BENGAL                   PURULIA
#
#      total_beneficiaries_IGNOAPS  total_beneficiaries_IGNDPS  \
# 0                           9404                       150.0
# 1                          13874                      1780.0
# 2                          14181                       766.0
# 3                        2659988                     88709.0
# 4                         165552                         0.0
# ..                           ...                         ...
# 728                       104736                      1061.0
# 729                      1079448                     60250.0
# 730                      1224987                     49714.0
# 731                       892569                     72783.0
# 732                       836504                     28929.0
#
#      total_beneficiaries_IGNWPS  Funds_Released_DHBS
# 0                        2290.0             0.000000
# 1                        3660.0             0.000000
# 2                        2014.0             0.000000
# 3                      799621.0             0.187200
# 4                       79096.0             0.187200
# ..                          ...                  ...
# 728                    139257.0             0.008261
# 729                    838762.0             0.008261
# 730                   1165481.0             0.008261
# 731                    580736.0             0.008261
# 732                    395344.0             0.008261
#
# [733 rows x 6 columns]

# %% [markdown]
# # stopped here; check for data errors

# %%
combined_dataset, unmatched_combinations = combine_datasets(combined_dataset, bharatnet_subset)
print('Unmatched Combinations:', unmatched_combinations)
print('Number of Combinations:', len(unmatched_combinations))
combined_dataset
# Out:
# Unmatched Combinations: {('ODISHA', 'ANUGUL'), ('JHARKHAND', 'HAZARIBAGH'), ('TELANGANA', 'YADADRI BHUVANAGIRI'), ('WEST BENGAL', 'MEDINIPUR EAST'), ('KARNATAKA', 'SHIVAMOGGA'), ('JAMMU AND KASHMIR', 'BUDGAM'), ('TAMIL NADU', 'RANIPET'), ('TAMIL NADU', 'SIVAGANGA'), ('TELANGANA', 'WARANGAL URBAN'), ('PUNJAB', 'S.A.S NAGAR'), ('MANIPUR', 'KAMJONG'), ('JAMMU AND KASHMIR', 'RAJOURI'), ('ODISHA', 'NABARANGPUR'), ('UTTAR PRADESH', 'BHADOHI'), ('ASSAM', 'SOUTH SALMARA-MANKACHAR'), ('TAMIL NADU', 'TENKASI'), ('GUJARAT', 'DOHAD'), ('JAMMU AND KASHMIR', 'GANDERBAL'), ('KARNATAKA', 'CHIKKAMAGALURU'), ('MANIPUR', 'NONEY'), ('ODISHA', 'BALANGIR'), ('TAMIL NADU', 'THIRUVALLUR'), ('MANIPUR', 'TENGNOUPAL'), ('KARNATAKA', 'VIJAYAPURA'), ('TELANGANA', 'WARANGAL RURAL'), ('MAHARASHTRA', 'AURANAGABAD'), ('MANIPUR', 'JIRIBAM'), ('KARNATAKA', 'BELAGAVI'), ('TAMIL NADU', 'TIRUCHIRAPPALLI'), ('TELANGANA', 'KUMURAM BHEEM ASIFABAD'), ('HARYANA', 'NUH'), ('UTTAR PRADESH', 'AMROHA'), ('UTTAR PRADESH', 'SAMBHAL'), ('UTTARAKHAND', 'TEHRI GARHWAL'), ('RAJASTHAN', 'KARAULI'), ('ARUNACHAL PRADESH', 'DIBANG VALLEY'), ('JHARKHAND', 'EAST SINGHBUM'), ('MADHYA PRADESH', 'EAST NIMAR'), ('UTTAR PRADESH', 'HATHRAS'), ('TAMIL NADU', 'CHENGALPATTU'), ('KARNATAKA', 'CHAMARAJANAGARA'), ('KARNATAKA', 'TUMAKURU'), ('CHHATTISGARH', 'RAJNANDGAON'), ('PUNJAB', 'SHAHID BHAGAT SINGH NAGAR'), ('PUNJAB', 'SRI MUKTSAR SAHIB'), ('PUNJAB', 'TARN TARAN'), ('KARNATAKA', 'MYSURU'), ('UTTAR PRADESH', 'KASGANJ'), ('WEST BENGAL', 'PURBA BARDHAMAN'), ('TAMIL NADU', 'KANCHIPURAM'), ('GUJARAT', 'CHHOTAUDEPUR'), ('ANDHRA PRADESH', 'Y.S.R.'), ('TELANGANA', 'RANGA REDDY'), ('KARNATAKA', 'BALLARI'), ('KARNATAKA', 'DAVANGERE'), ('PUDUCHERRY', 'KARAIKAL'), ('MANIPUR', 'PHERZAWL'), ('CHHATTISGARH', 'GAURELLA PENDRA MARWAHI'), ('MANIPUR', 'KANGPOKPI'), ('TAMIL NADU', 'TIRUPATHUR'), ('TAMIL NADU', 'TUTICORIN'), ('WEST BENGAL', 'MEDINIPUR WEST'), ('KARNATAKA', 'KALABURAGI'), ('MANIPUR', 'KAKCHING'), ('HARYANA', 'MAHENDRAGARH'), ('WEST BENGAL', 'PASCHIM BARDHAMAN'), ('ASSAM', 'WEST KARBI ANGLONG'), ('TAMIL NADU', 'KANNIYAKUMARI'), ('TAMIL NADU', 'VILLUPURAM'), ('MADHYA PRADESH', 'NIWARI'), ('TELANGANA', 'JAYASHANKAR BHUPALAPALLY'), ('CHHATTISGARH', 'BALODA BAZAR'), ('KARNATAKA', 'DHARWAD'), ('TAMIL NADU', 'KALLAKURICHI'), ('TELANGANA', 'MEDCHAL MALKAJGIRI'), ('ODISHA', 'JAJAPUR')}
# Number of Combinations: 76
#               state_name             district_name  \
# 0    ANDAMAN AND NICOBAR                  NICOBARS
# 1    ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR            SOUTH ANDAMANS
# 3         ANDHRA PRADESH                 ANANTAPUR
# 4         ANDHRA PRADESH     Alluri Sitharama Raju
# ..                   ...                       ...
# 804          WEST BENGAL         PASCHIM MEDINIPUR
# 805          WEST BENGAL           PURBA BARDHAMAN
# 806          WEST BENGAL             PURBA BURDWAN
# 807          WEST BENGAL           PURBA MEDINIPUR
# 808          WEST BENGAL                   PURULIA
#
#      total_beneficiaries_IGNOAPS  total_beneficiaries_IGNDPS  \
# 0                         9404.0                       150.0
# 1                        13874.0                      1780.0
# 2                        14181.0                       766.0
# 3                      2659988.0                     88709.0
# 4                       165552.0                         0.0
# ..                           ...                         ...
# 804                    1079448.0                     60250.0
# 805                          NaN                         NaN
# 806                    1224987.0                     49714.0
# 807                     892569.0                     72783.0
# 808                     836504.0                     28929.0
#
#      total_beneficiaries_IGNWPS  Funds_Released_DHBS  \
# 0                        2290.0             0.000000
# 1                        3660.0             0.000000
# 2                        2014.0             0.000000
# 3                      799621.0             0.187200
# 4                       79096.0             0.187200
# ..                          ...                  ...
# 804                    838762.0             0.008261
# 805                         NaN                  NaN
# 806                   1165481.0             0.008261
# 807                    580736.0             0.008261
# 808                    395344.0             0.008261
#
#      Percentage_Service_Ready_Gram_Panchayats
# 0                                   87.500000
# 1                                  100.000000
# 2                                  100.000000
# 3                                   95.402299
# 4                                         NaN
# ..                                        ...
# 804                                       NaN
# 805                                 67.906977
# 806                                       NaN
# 807                                       NaN
# 808                                100.000000
#
# [809 rows x 7 columns]

# %%
combined_dataset, unmatched_combinations = combine_datasets(combined_dataset, active_companies_subset)
print('Unmatched Combinations:', unmatched_combinations)
print('Number of Combinations:', len(unmatched_combinations))
combined_dataset
# Out:
# Unmatched Combinations: {'THE DADRA & NAGAR HAVELI AND DAMAN AND DIU', 'DADAR NAGAR HAVELI'}
# Number of Combinations: 2
#               state_name             district_name  \
# 0    ANDAMAN AND NICOBAR                  NICOBARS
# 1    ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR            SOUTH ANDAMANS
# 3         ANDHRA PRADESH                 ANANTAPUR
# 4         ANDHRA PRADESH     Alluri Sitharama Raju
# ..                   ...                       ...
# 806          WEST BENGAL         PASCHIM MEDINIPUR
# 807          WEST BENGAL           PURBA BARDHAMAN
# 808          WEST BENGAL             PURBA BURDWAN
# 809          WEST BENGAL           PURBA MEDINIPUR
# 810          WEST BENGAL                   PURULIA
#
#      total_beneficiaries_IGNOAPS  total_beneficiaries_IGNDPS  \
# 0                         9404.0                       150.0
# 1                        13874.0                      1780.0
# 2                        14181.0                       766.0
# 3                      2659988.0                     88709.0
# 4                       165552.0                         0.0
# ..                           ...                         ...
# 806                    1079448.0                     60250.0
# 807                          NaN                         NaN
# 808                    1224987.0                     49714.0
# 809                     892569.0                     72783.0
# 810                     836504.0                     28929.0
#
#      total_beneficiaries_IGNWPS  Funds_Released_DHBS  \
# 0                        2290.0             0.000000
# 1                        3660.0             0.000000
# 2                        2014.0             0.000000
# 3                      799621.0             0.187200
# 4                       79096.0             0.187200
# ..                          ...                  ...
# 806                    838762.0             0.008261
# 807                         NaN                  NaN
# 808                   1165481.0             0.008261
# 809                    580736.0             0.008261
# 810                    395344.0             0.008261
#
#      Percentage_Service_Ready_Gram_Panchayats  No. of Companies - Public  \
# 0                                   87.500000                   0.666667
# 1                                  100.000000                   0.666667
# 2                                  100.000000                   0.666667
# 3                                   95.402299                   1.961538
# 4                                         NaN                   1.961538
# ..                                        ...                        ...
# 806                                       NaN                   2.518519
# 807                                 67.906977                   2.518519
# 808                                       NaN                   2.518519
# 809                                       NaN                   2.518519
# 810                                100.000000                   2.518519
#
#      AuthorizedCapital_Public (In Crores)  No. of Companies - Private  \
# 0                                0.666667                    0.333333
# 1                                0.666667                    0.333333
# 2                                0.666667                    0.333333
# 3                              606.567308                    1.384615
# 4                              606.567308                    1.384615
# ..                                    ...                         ...
# 806                           1945.581481                    1.259259
# 807                           1945.581481                    1.259259
# 808                           1945.581481                    1.259259
# 809                           1945.581481                    1.259259
# 810                           1945.581481                    1.259259
#
#      AuthorizedCapital_Private  (In Crores)
# 0                                 16.666667
# 1                                 16.666667
# 2                                 16.666667
# 3                                 43.691923
# 4                                 43.691923
# ..                                      ...
# 806                              328.139630
# 807                              328.139630
# 808                              328.139630
# 809                              328.139630
# 810                              328.139630
#
# [811 rows x 11 columns]

# %% [markdown]
# # Give the Zones classification

# %%
india_zones = {
    "Northern Zone": {
        "States": ["Haryana", "Himachal Pradesh", "Punjab", "Rajasthan", "Uttarakhand", "Uttar Pradesh"],
        "Union Territories": ["Delhi", "Ladakh", "Jammu And Kashmir", "Chandigarh"]
    },
    "Southern Zone": {
        "States": ["Andhra Pradesh", "Karnataka", "Kerala", "Tamil Nadu", "Telangana"],
        "Union Territories": ["Puducherry", "Lakshadweep", "Andaman And Nicobar"]
    },
    "Eastern Zone": {
        "States": ["Bihar", "Jharkhand", "Odisha", "West Bengal"]
    },
    "Western Zone": {
        "States": ["Goa", "Gujarat", "Maharashtra"],
        "Union Territories": ["The Dadra and Nagar Haveli and Daman and Diu"]
    },
    "Central Zone": {
        "States": ["Chhattisgarh", "Madhya Pradesh"]
    },
    "North-Eastern Zone": {
        "States": ["Arunachal Pradesh", "Assam", "Manipur", "Meghalaya", "Mizoram", "Nagaland", "Tripura", "Sikkim"]
    }
}



# Accessing the zones
for zone, divisions in india_zones.items():
    print(f"{zone}:")
    for division, places in divisions.items():
        print(f"  {division}: {', '.join(places)}")
    print()
# Out:
# Northern Zone:
#   States: Haryana, Himachal Pradesh, Punjab, Rajasthan, Uttarakhand, Uttar Pradesh
#   Union Territories: Delhi, Ladakh, Jammu And Kashmir, Chandigarh
#
# Southern Zone:
#   States: Andhra Pradesh, Karnataka, Kerala, Tamil Nadu, Telangana
#   Union Territories: Puducherry, Lakshadweep, Andaman And Nicobar
#
# Eastern Zone:
#   States: Bihar, Jharkhand, Odisha, West Bengal
#
# Western Zone:
#   States: Goa, Gujarat, Maharashtra
#   Union Territories: The Dadra and Nagar Haveli and Daman and Diu
#
# Central Zone:
#   States: Chhattisgarh, Madhya Pradesh
#
# North-Eastern Zone:
#   States: Arunachal Pradesh, Assam, Manipur, Meghalaya, Mizoram, Nagaland, Tripura, Sikkim

# %%
combined_dataset
# Out:
#               state_name             district_name  \
# 0    ANDAMAN AND NICOBAR                  NICOBARS
# 1    ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR            SOUTH ANDAMANS
# 3         ANDHRA PRADESH                 ANANTAPUR
# 4         ANDHRA PRADESH     Alluri Sitharama Raju
# ..                   ...                       ...
# 728          WEST BENGAL           PASCHIM BURDWAN
# 729          WEST BENGAL         PASCHIM MEDINIPUR
# 730          WEST BENGAL             PURBA BURDWAN
# 731          WEST BENGAL           PURBA MEDINIPUR
# 732          WEST BENGAL                   PURULIA
#
#      total_beneficiaries_IGNOAPS  total_beneficiaries_IGNDPS  \
# 0                           9404                       150.0
# 1                          13874                      1780.0
# 2                          14181                       766.0
# 3                        2659988                     88709.0
# 4                         165552                         0.0
# ..                           ...                         ...
# 728                       104736                      1061.0
# 729                      1079448                     60250.0
# 730                      1224987                     49714.0
# 731                       892569                     72783.0
# 732                       836504                     28929.0
#
#      total_beneficiaries_IGNWPS  Funds_Released_DHBS
# 0                        2290.0             0.000000
# 1                        3660.0             0.000000
# 2                        2014.0             0.000000
# 3                      799621.0             0.187200
# 4                       79096.0             0.187200
# ..                          ...                  ...
# 728                    139257.0             0.008261
# 729                    838762.0             0.008261
# 730                   1165481.0             0.008261
# 731                    580736.0             0.008261
# 732                    395344.0             0.008261
#
# [733 rows x 6 columns]

# %%
# Create a new column where you assign each row a zone name based on the 'state_name' column
# Note that the 'state_name' column has all values as uppercase
def assign_zone(state_name):
    state_name = state_name.lower()
    for zone, divisions in india_zones.items():
        for division, places in divisions.items():
            # convert places to lower case
            places = [place.lower() for place in places]
            if state_name in places:
                return zone

combined_dataset['Zone'] = combined_dataset['state_name'].apply(assign_zone)
combined_dataset
# Out:
#               state_name             district_name  \
# 0    ANDAMAN AND NICOBAR                  NICOBARS
# 1    ANDAMAN AND NICOBAR  NORTH AND MIDDLE ANDAMAN
# 2    ANDAMAN AND NICOBAR            SOUTH ANDAMANS
# 3         ANDHRA PRADESH                 ANANTAPUR
# 4         ANDHRA PRADESH     Alluri Sitharama Raju
# ..                   ...                       ...
# 728          WEST BENGAL           PASCHIM BURDWAN
# 729          WEST BENGAL         PASCHIM MEDINIPUR
# 730          WEST BENGAL             PURBA BURDWAN
# 731          WEST BENGAL           PURBA MEDINIPUR
# 732          WEST BENGAL                   PURULIA
#
#      total_beneficiaries_IGNOAPS  total_beneficiaries_IGNDPS  \
# 0                           9404                       150.0
# 1                          13874                      1780.0
# 2                          14181                       766.0
# 3                        2659988                     88709.0
# 4                         165552                         0.0
# ..                           ...                         ...
# 728                       104736                      1061.0
# 729                      1079448                     60250.0
# 730                      1224987                     49714.0
# 731                       892569                     72783.0
# 732                       836504                     28929.0
#
#      total_beneficiaries_IGNWPS  Funds_Released_DHBS           Zone
# 0                        2290.0             0.000000  Southern Zone
# 1                        3660.0             0.000000  Southern Zone
# 2                        2014.0             0.000000  Southern Zone
# 3                      799621.0             0.187200  Southern Zone
# 4                       79096.0             0.187200  Southern Zone
# ..                          ...                  ...            ...
# 728                    139257.0             0.008261   Eastern Zone
# 729                    838762.0             0.008261   Eastern Zone
# 730                   1165481.0             0.008261   Eastern Zone
# 731                    580736.0             0.008261   Eastern Zone
# 732                    395344.0             0.008261   Eastern Zone
#
# [733 rows x 7 columns]

# %%
# Check for null values
combined_dataset.isnull().sum()
# Out:
# state_name                     0
# district_name                  0
# total_beneficiaries_IGNOAPS    0
# total_beneficiaries_IGNDPS     0
# total_beneficiaries_IGNWPS     0
# Funds_Released_DHBS            0
# Zone                           0
# dtype: int64

# %%
# Select all the columns except the first two columns as a dataframe
combined_dataset_subset = combined_dataset.iloc[:, 2:]
combined_dataset_subset
# Out:
#      total_beneficiaries_IGNOAPS  total_beneficiaries_IGNDPS  \
# 0                           9404                       150.0
# 1                          13874                      1780.0
# 2                          14181                       766.0
# 3                        2659988                     88709.0
# 4                         165552                         0.0
# ..                           ...                         ...
# 728                       104736                      1061.0
# 729                      1079448                     60250.0
# 730                      1224987                     49714.0
# 731                       892569                     72783.0
# 732                       836504                     28929.0
#
#      total_beneficiaries_IGNWPS  Funds_Released_DHBS           Zone
# 0                        2290.0             0.000000  Southern Zone
# 1                        3660.0             0.000000  Southern Zone
# 2                        2014.0             0.000000  Southern Zone
# 3                      799621.0             0.187200  Southern Zone
# 4                       79096.0             0.187200  Southern Zone
# ..                          ...                  ...            ...
# 728                    139257.0             0.008261   Eastern Zone
# 729                    838762.0             0.008261   Eastern Zone
# 730                   1165481.0             0.008261   Eastern Zone
# 731                    580736.0             0.008261   Eastern Zone
# 732                    395344.0             0.008261   Eastern Zone
#
# [733 rows x 5 columns]

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, f1_score

df = combined_dataset_subset

X = df.drop(columns=['Zone'])
y = df['Zone']

num_classes = len(y.unique())

# Encode categorical target labels
y_encoded = LabelEncoder().fit_transform(y)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# One-vs-Rest Logistic Regression
clf = LogisticRegression(multi_class='ovr', max_iter=1000, random_state=42)
clf.fit(X_train, y_train)

# Predict on the test set
y_pred = clf.predict(X_test)

# Classification Report
class_report = classification_report(y_test, y_pred, target_names=[f'class_{i}' for i in range(1, num_classes + 1)])

# Calculate and print classwise F1 scores
f1_scores = f1_score(y_test, y_pred, average=None)
for i, score in enumerate(f1_scores):
    print(f"F1 Score for class_{i + 1}: {score:.2f}")

print("\nClassification Report:")
print(class_report)
# Out:
# F1 Score for class_1: 0.11
# F1 Score for class_2: 0.48
# F1 Score for class_3: 0.74
# F1 Score for class_4: 0.49
# F1 Score for class_5: 0.51
# F1 Score for class_6: 0.24
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      class_1       0.50      0.06      0.11        16
#      class_2       0.46      0.50      0.48        24
#      class_3       0.71      0.77      0.74        31
#      class_4       0.44      0.56      0.49        41
#      class_5       0.50      0.52      0.51        25
#      class_6       0.29      0.20      0.24        10
#
#     accuracy                           0.51       147
#    macro avg       0.48      0.44      0.43       147
# weighted avg       0.51      0.51      0.49       147
# c:\Users\Sachin\anaconda3\envs\dsc\Lib\site-packages\sklearn\linear_model\_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
